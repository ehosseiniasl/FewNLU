# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from matplotlib.transforms import Affine2D

import warnings
warnings.filterwarnings('ignore')

# %%
def plot_hyperparams(dev32, cv, mdl, title=''):
    fig, (ax0, ax1, ax2, ax3) = plt.subplots(ncols=4, sharey=True, figsize=(30,8))
    hp=0

    trans1 = Affine2D().translate(0.0, 0.0) + ax0.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax0.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax0.transData
    er1 = ax0.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax0.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax0.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
    ax0.set_title("HP1")
    ax0.set_xlabel('# shots')
    # ax0.legend(loc="upper right")
    # plt.show()
    ax0.grid()


    hp=1
    trans1 = Affine2D().translate(0.0, 0.0) + ax1.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax1.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax1.transData
    er1 = ax1.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax1.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax1.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
#     ax1.set_title(f"{TASK}, HP2")
    ax1.set_title("HP2")
    ax1.set_xlabel('# shots')
    # ax1.legend(loc="upper right")
    # plt.show()
    ax1.grid()

    hp=2
    trans1 = Affine2D().translate(0.0, 0.0) + ax2.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax2.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax2.transData
    er1 = ax2.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax2.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax2.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
    ax2.set_title("HP3")
    ax2.set_xlabel('# shots')
    # ax2.legend(loc="upper right")
    # plt.show()
    ax2.grid()

    hp=3
    trans1 = Affine2D().translate(0.0, 0.0) + ax3.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax3.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax3.transData
    er1 = ax3.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax3.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax3.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
    ax3.set_title("HP4")
    ax3.legend(loc="lower left")
    ax3.set_xlabel('# shots')

    # plt.show()ac
    ax3.grid()
    fig = plt.gcf()
    fig.suptitle(title, fontsize=30)
    return

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)
    return

def plot_bar(data_a, data_b, data_c, ymin=0.4, ymax=0.6):
    ticks = ['8', '16', '32', '64']
    
    plt.figure(figsize=(8,5))

    bpc = plt.boxplot(data_a, positions=np.array(range(len(data_a)))*2.0, widths=0.4)
    bpl = plt.boxplot(data_b, positions=np.array(range(len(data_b)))*2.0-0.45, widths=0.4)
    bpr = plt.boxplot(data_c, positions=np.array(range(len(data_c)))*2.0+0.45, widths=0.4)
    set_box_color(bpc, 'b')
    set_box_color(bpl, 'r')
    set_box_color(bpr, 'g')

    plt.plot([], c='b', label='multisplit')
    plt.plot([], c='r', label='cv')
    plt.plot([], c='g', label='mdl')

    plt.legend(loc='lower right')

    plt.xticks(range(0, len(ticks) * 2, 2), ticks)
    plt.xlim(-2, len(ticks)*2)
    plt.ylim(ymin, ymax)
    plt.tight_layout()
    plt.grid()
    plt.title(f"{TASK}")
    plt.xlabel('# shots')
    return

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)
    return

def plot_bar_models(data_a, label_a, data_b, label_b, data_c, label_c, ymin=0.4, ymax=0.6):
    ticks = ['8', '16', '32', '64']
    
    plt.figure(figsize=(8,5))

    bpl = plt.boxplot(data_a, positions=np.array(range(len(data_b)))*2.0-0.45, widths=0.4)
    bpc = plt.boxplot(data_b, positions=np.array(range(len(data_a)))*2.0, widths=0.4)
    bpr = plt.boxplot(data_c, positions=np.array(range(len(data_c)))*2.0+0.45, widths=0.4)
    set_box_color(bpl, 'b')
    set_box_color(bpc, 'r')
    set_box_color(bpr, 'g')

#     plt.plot([], c='b', label='bert-base')
#     plt.plot([], c='r', label='albert-base')
#     plt.plot([], c='g', label='albert-xxlarge')

    plt.plot([], c='b', label=label_a)
    plt.plot([], c='r', label=label_b)
    plt.plot([], c='g', label=label_c)

    plt.legend(loc='lower right')

    plt.xticks(range(0, len(ticks) * 2, 2), ticks)
    plt.xlim(-2, len(ticks)*2)
    plt.ylim(ymin, ymax)
    plt.tight_layout()
    plt.grid()
    plt.title(f"{TASK}")
    plt.xlabel('# shots')
    return

# %%
# BoolQ
# Albert-xxlarge-v2

# TASK="BoolQ"
TITLE='task=BoolQ, metric=accuracy, model=Albert-xxlarge-v2'

# plt.figure(figsize=(10,10))
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [[0.4879, 0.532, 0.48065, 0.506422],
             [0.5454, 0.43922, 0.4788, 0.48035],
             [0.5686, 0.5464, 0.559, 0.510856],
             [0.6064, 0.5119, 0.6064, 0.5225535]],
    'std': [[0.0958,0.04465,0.04757,0.056919],
            [0.06201,0.07297,0.0461,0.0543496],
            [0.05185,0.03084,0.054,0.025548],
            [0.02575,0.0829,0.02575,0.07731036]
           ]
}

cv = {
        'mean': [
            [0.51276, 0.5183, 0.553, 0.561697],
            [0.5954, 0.5808, 0.589, 0.5561927],
            [0.583, 0.5264, 0.548, 0.548471],
            [0.582, 0.5551, 0.535, 0.5626911]
        ],
    'std': [
        [0.0805,0.0423,0.056,0.029084],
        [0.0446,0.0298,0.034,0.027265],
        [0.026,0.0475,0.026,0.0440519],
        [0.046,0.0409,0.086,0.061017]
           ]
}

mdl = {
    'mean': [
        [0.572, 0.568, 0.532, 0.56307339],
        [0.463, 0.593, 0.525, 0.566513],
        [0.527, 0.573, 0.52, 0.549694],
        [0.601, 0.546, 0.502, 0.544266]
    ],
    
    'std': [
        [0.053,0.055,0.066,0.069738],
        [0.105,0.028,0.039,0.0736753],
        [0.088,0.037,0.022,0.029377],
        [0.042,0.093,0.0607,0.0198083]
    ]
}

plot_hyperparams(dev32, cv, mdl, TITLE)

# %%
# BoolQ
# Albert-base-v2

# TASK="BoolQ"
TITLE='task=BoolQ, metric=accuracy, model=Albert-base-v2'

# plt.figure(figsize=(10,10))
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
        [0.611, 0.576, 0.52, 0.555],
[0.619, 0.572, 0.51, 0.575],
[0.613, 0.586, 0.513, 0.566],
[0.613, 0.576, 0.531, 0.575]        
    ],
    'std': [
        [0.0112,0.0452,0.039,0.024],
[0.0046,0.051,0.0106,0.0128],
[0.0149,0.019,0.0306,0.028],
[0.0109,0.0251,0.014,0.029]
           ]
}

cv = {
        'mean': [
            [0.615, 0.579, 0.505, 0.552],
[0.616, 0.59, 0.507, 0.555],
[0.619, 0.589, 0.508, 0.548],
[0.617, 0.588, 0.522, 0.55]
        ],
    'std': [
        [0.009,0.039,0.035,0.028],
[0.015,0.029,0.031,0.029],
[0.003,0.021,0.03,0.019],
[0.005,0.013,0.047,0.026]
           ]
}

mdl = {
    'mean': [
        [0.581, 0.613, 0.488, 0.576],
[0.554, 0.608, 0.506, 0.579],
[0.586, 0.604, 0.494, 0.578],
[0.582, 0.603, 0.498, 0.577]
    ],
    
    'std': [
        [0.029,0.01,0.019,0.006],
[0.083,0.011,0.036,0.00218],
[0.035,0.018,0.022,0.0084],
[0.043,0.015,0.022,0.009]
    ]
}

plot_hyperparams(dev32, cv, mdl, TITLE)

# %%
# BoolQ
# bert-base

# TASK="BoolQ"
TITLE='task=BoolQ, metric=accuracy, model=bert-base'

# plt.figure(figsize=(10,10))
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
        [0.61, 0.599, 0.561, 0.574],
[0.603, 0.592, 0.552, 0.572],
[0.542, 0.561, 0.527, 0.577],
[0.561, 0.568, 0.531, 0.578]

    ],
    'std': [
        [0.025,0.018,0.004,0.038],
[0.038,0.02,0.02,0.038],
[0.094,0.052,0.045,0.039],
[0.078,0.046,0.053,0.038]
           ]
}

cv = {
        'mean': [
            [0.615, 0.589, 0.551, 0.58],
[0.614, 0.591, 0.543, 0.572],
[0.573, 0.549, 0.527, 0.579],
[0.593, 0.547, 0.532, 0.573]
        ],
    'std': [
        [0.0117,0.04,0.041,0.023],
[0.013,0.038,0.045,0.016],
[0.054,0.086,0.05,0.05],
[0.025,0.092,0.04,0.044]
           ]
}

mdl = {
    'mean': [
        [0.605, 0.616, 0.513, 0.553],
[0.608, 0.616, 0.516, 0.559],
[0.532, 0.609, 0.503, 0.572],
[0.555, 0.611, 0.486, 0.579]
    ],
    
    'std': [
        [0.021,0.0087,0.035,0.019],
[0.0026,0.0102,0.032,0.017],
[0.087,0.0083,0.057,0.0188],
[0.089,0.00718,0.045,0.0085]
    ]
}

plot_hyperparams(dev32, cv, mdl, TITLE)

# %%
#BoolQ
# Albert-xxlarge-v2

# TASK = 'BoolQ, accuracy mean value'
TASK = 'BoolQ, metric=accuracy mean value, model=Albert-xxlarge-v2'

matplotlib.rcParams.update({'font.size':15})


data = {
    'dev32': {
            '8': {
                'mean': [0.4879, 0.5454, 0.5686, 0.6064],
                'std': [0.0958, 0.06201, 0.05185, 0.02575]
            },
            '16': {
                'mean': [0.532, 0.43922, 0.5464, 0.5119],
                'std': [0.04465, 0.07297, 0.03084, 0.0829]
            },

            '32': {
                'mean': [0.48065, 0.4788, 0.559, 0.6064],
                'std': [0.04757, 0.0461, 0.054, 0.02575]
            },
            '64': {
                'mean': [0.506422, 0.48035, 0.510856, 0.5225535],
                'std': [0.056919, 0.0543496, 0.025548, 0.07731036]
            }
    },
    
    'cv': {
            '8': {
                'mean': [0.51276, 0.5954, 0.583, 0.582],
                'std': [0.0805, 0.0446, 0.026, 0.046]
            },
            '16': {
                'mean': [0.5183, 0.5808, 0.5264, 0.5551],
                'std': [0.0423, 0.0298, 0.0475, 0.0409]
            },

            '32': {
                'mean': [0.553, 0.589, 0.548, 0.535],
                'std': [0.056, 0.034, 0.026, 0.086]
            },
            '64': {
                'mean': [0.561697, 0.5561927, 0.548471, 0.5626911],
                'std': [0.029084, 0.027265, 0.0440519, 0.061017]
            }
    },
    
    'mdl': {
            '8': {
                'mean': [0.572, 0.463, 0.527, 0.601],
                'std': [0.053, 0.105, 0.088, 0.042]
            },
            '16': {
                'mean': [0.568, 0.593, 0.573, 0.546],
                'std': [0.055, 0.028, 0.037, 0.093]
            },

            '32': {
                'mean': [0.532, 0.525, 0.52, 0.502],
                'std': [0.066, 0.039, 0.022, 0.0607]
            },
            '64': {
                'mean': [0.56307339, 0.566513, 0.549694, 0.544266],
                'std': [0.069738, 0.0736753, 0.029377, 0.0198083]
            }
    }
    

}

data_a = [data['dev32']['8']['mean'], 
             data['dev32']['16']['mean'], 
             data['dev32']['32']['mean'], 
             data['dev32']['64']['mean'], 
            ]

data_b = [data['cv']['8']['mean'], 
             data['cv']['16']['mean'], 
             data['cv']['32']['mean'], 
             data['cv']['64']['mean'], 
            ]

data_c = [data['mdl']['8']['mean'], 
             data['mdl']['16']['mean'], 
             data['mdl']['32']['mean'], 
             data['mdl']['64']['mean'], 
            ]

plot_bar(data_a, data_b, data_c, ymin=.4, ymax=0.65)

# %%
# BoolQ STD
# Albert-xxlarge-v2

# TASK = "BoolQ, accuracy standard deviation"
TASK = 'BoolQ, metric=accuracy standard deviation, model=Albert-xxlarge-v2'

data_a = [data['dev32']['8']['std'], 
             data['dev32']['16']['std'], 
             data['dev32']['32']['std'], 
             data['dev32']['64']['std'], 
            ]

data_b = [data['cv']['8']['std'], 
             data['cv']['16']['std'], 
             data['cv']['32']['std'], 
             data['cv']['64']['std'], 
            ]

data_c = [data['mdl']['8']['std'], 
             data['mdl']['16']['std'], 
             data['mdl']['32']['std'], 
             data['mdl']['64']['std'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0, ymax=0.12)

# %%
#BoolQ
# Albert-base-v2

# TASK = 'BoolQ, accuracy mean value'
TASK = 'BoolQ, metric=accuracy mean value, model=Albert-base-v2'

matplotlib.rcParams.update({'font.size':15})


data = {
    'dev32': {
            '8': {
                'mean': [0.611, 0.619, 0.613, 0.613],
                'std': []
            },
            '16': {
                'mean': [0.576, 0.572, 0.586, 0.576],
                'std': []
            },

            '32': {
                'mean': [0.52,0.51,0.513,0.531],
                'std': []
            },
            '64': {
                'mean': [0.555,0.575,0.566,0.575],
                'std': []
            }
    },
    
    'cv': {
            '8': {
                'mean': [0.615,0.616,0.619,0.617],
                'std': []
            },
            '16': {
                'mean': [0.579,0.59,0.589,0.588],
                'std': []
            },

            '32': {
                'mean': [0.505,0.507,0.508,0.522],
                'std': []
            },
            '64': {
                'mean': [0.552,0.555,0.548,0.55],
                'std': []
            }
    },
    
    'mdl': {
            '8': {
                'mean': [0.581,0.554,0.586,0.582],
                'std': []
            },
            '16': {
                'mean': [0.613,0.608,0.604,0.603],
                'std': []
            },

            '32': {
                'mean': [0.488,0.506,0.494,0.498],
                'std': []
            },
            '64': {
                'mean': [0.576,0.579,0.578,0.577],
                'std': []
            }
    }
    

}

data_a = [data['dev32']['8']['mean'], 
             data['dev32']['16']['mean'], 
             data['dev32']['32']['mean'], 
             data['dev32']['64']['mean'], 
            ]

data_b = [data['cv']['8']['mean'], 
             data['cv']['16']['mean'], 
             data['cv']['32']['mean'], 
             data['cv']['64']['mean'], 
            ]

data_c = [data['mdl']['8']['mean'], 
             data['mdl']['16']['mean'], 
             data['mdl']['32']['mean'], 
             data['mdl']['64']['mean'], 
            ]

plot_bar(data_a, data_b, data_c, ymin=.45, ymax=0.65)

# %%
#BoolQ
# bert-base-v2

# TASK = 'BoolQ, accuracy mean value'
TASK = 'BoolQ, metric=accuracy mean value, model=bert-base-v2'

matplotlib.rcParams.update({'font.size':15})


data = {
    'dev32': {
            '8': {
                'mean': [0.61, 0.603, 0.542, 0.561],
                'std': []
            },
            '16': {
                'mean': [0.599, 0.592, 0.561, 0.568],
                'std': []
            },

            '32': {
                'mean': [0.561, 0.552, 0.527, 0.531],
                'std': []
            },
            '64': {
                'mean': [0.574, 0.572, 0.577, 0.578],
                'std': []
            }
    },
    
    'cv': {
            '8': {
                'mean': [0.615,0.614,0.573,0.593],
                'std': []
            },
            '16': {
                'mean': [0.589,0.591,0.549,0.547],
                'std': []
            },

            '32': {
                'mean': [0.551,0.543,0.527,0.532],
                'std': []
            },
            '64': {
                'mean': [0.58,0.572,0.579,0.573],
                'std': []
            }
    },
    
    'mdl': {
            '8': {
                'mean': [0.605,0.608,0.532,0.555],
                'std': []
            },
            '16': {
                'mean': [0.616,0.616,0.609,0.611],
                'std': []
            },

            '32': {
                'mean': [0.513,0.516,0.503,0.486],
                'std': []
            },
            '64': {
                'mean': [0.553,0.559,0.572,0.579],
                'std': []
            }
    }
    

}

data_a = [data['dev32']['8']['mean'], 
             data['dev32']['16']['mean'], 
             data['dev32']['32']['mean'], 
             data['dev32']['64']['mean'], 
            ]

data_b = [data['cv']['8']['mean'], 
             data['cv']['16']['mean'], 
             data['cv']['32']['mean'], 
             data['cv']['64']['mean'], 
            ]

data_c = [data['mdl']['8']['mean'], 
             data['mdl']['16']['mean'], 
             data['mdl']['32']['mean'], 
             data['mdl']['64']['mean'], 
            ]

plot_bar(data_a, data_b, data_c, ymin=.45, ymax=0.65)

# %%
#BoolQ
# dev32 - All models

# TASK = 'BoolQ, accuracy mean value'
TASK = 'BoolQ, metric=accuracy mean value, method=multisplit'

matplotlib.rcParams.update({'font.size':15})


data = {
    'bert-base': {
            '8': {
                'mean': [0.61, 0.603, 0.542, 0.561],
                'std': []
            },
            '16': {
                'mean': [0.599, 0.592, 0.561, 0.568],
                'std': []
            },

            '32': {
                'mean': [0.561, 0.552, 0.527, 0.531],
                'std': []
            },
            '64': {
                'mean': [0.574, 0.572, 0.577, 0.578],
                'std': []
            }
    },
    
    'albert-base': {
            '8': {
                'mean': [0.611, 0.619, 0.613, 0.613],
                'std': []
            },
            '16': {
                'mean': [0.576, 0.572, 0.586, 0.576],
                'std': []
            },

            '32': {
                'mean': [0.52,0.51,0.513,0.531],
                'std': []
            },
            '64': {
                'mean': [0.555,0.575,0.566,0.575],
                'std': []
            }
    },
    
    'albert-xxlarge': {
            '8': {
                'mean': [0.4879, 0.5454, 0.5686, 0.6064],
                'std': []
            },
            '16': {
                'mean': [0.532, 0.43922, 0.5464, 0.5119],
                'std': []
            },

            '32': {
                'mean': [0.48065, 0.4788, 0.559, 0.6064],
                'std': []
            },
            '64': {
                'mean': [0.506422, 0.48035, 0.510856, 0.5225535],
                'std': []
            }
    }
    

}


data_a = [data['albert-base']['8']['mean'], 
             data['albert-base']['16']['mean'], 
             data['albert-base']['32']['mean'], 
             data['albert-base']['64']['mean'], 
            ]


data_b = [data['bert-base']['8']['mean'], 
             data['bert-base']['16']['mean'], 
             data['bert-base']['32']['mean'], 
             data['bert-base']['64']['mean'], 
            ]


data_c = [data['albert-xxlarge']['8']['mean'], 
             data['albert-xxlarge']['16']['mean'], 
             data['albert-xxlarge']['32']['mean'], 
             data['albert-xxlarge']['64']['mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=.4, ymax=0.65)

data_a = [data['albert-base']['8']['mean'], 
             data['albert-base']['16']['mean'], 
             data['albert-base']['32']['mean'], 
             data['albert-base']['64']['mean'], 
            ]

plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.4, ymax=0.65)

# %%
#BoolQ
# CV - All models

# TASK = 'BoolQ, accuracy mean value'
TASK = 'BoolQ, metric=accuracy mean value, method=cross validation'

matplotlib.rcParams.update({'font.size':15})


data = {
    'bert-base': {
            '8': {
                'mean': [0.615,0.614,0.573,0.593],
                'std': []
            },
            '16': {
                'mean': [0.589,0.591,0.549,0.547],
                'std': []
            },

            '32': {
                'mean': [0.551,0.543,0.527,0.532],
                'std': []
            },
            '64': {
                'mean': [0.58,0.572,0.579,0.573],
                'std': []
            }
    },
    
    'albert-base': {
            '8': {
                'mean': [0.615,0.616,0.619,0.617],
                'std': []
            },
            '16': {
                'mean': [0.579,0.59,0.589,0.588],
                'std': []
            },

            '32': {
                'mean': [0.505,0.507,0.508,0.522],
                'std': []
            },
            '64': {
                'mean': [0.552,0.555,0.548,0.55],
                'std': []
            }
    },
    
    'albert-xxlarge': {
            '8': {
                'mean': [0.51276, 0.5954, 0.583, 0.582],
                'std': []
            },
            '16': {
                'mean': [0.5183, 0.5808, 0.5264, 0.5551],
                'std': []
            },

            '32': {
                'mean': [0.553, 0.589, 0.548, 0.535],
                'std': []
            },
            '64': {
                'mean': [0.561697, 0.5561927, 0.548471, 0.5626911],
                'std': []
            }
    }
    

}


data_a = [data['albert-base']['8']['mean'], 
             data['albert-base']['16']['mean'], 
             data['albert-base']['32']['mean'], 
             data['albert-base']['64']['mean'], 
            ]


data_b = [data['bert-base']['8']['mean'], 
             data['bert-base']['16']['mean'], 
             data['bert-base']['32']['mean'], 
             data['bert-base']['64']['mean'], 
            ]


data_c = [data['albert-xxlarge']['8']['mean'], 
             data['albert-xxlarge']['16']['mean'], 
             data['albert-xxlarge']['32']['mean'], 
             data['albert-xxlarge']['64']['mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=.4, ymax=0.65)
plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.4, ymax=0.65)

# %%
#BoolQ
# CV - All models

# TASK = 'BoolQ, accuracy mean value'
TASK = 'BoolQ, metric=accuracy mean value, method=mdl'

matplotlib.rcParams.update({'font.size':15})


data = {
    'bert-base': {
            '8': {
                'mean': [0.605,0.608,0.532,0.555],
                'std': []
            },
            '16': {
                'mean': [0.616,0.616,0.609,0.611],
                'std': []
            },

            '32': {
                'mean': [0.513,0.516,0.503,0.486],
                'std': []
            },
            '64': {
                'mean': [0.553,0.559,0.572,0.579],
                'std': []
            }
    },
    
    'albert-base': {
            '8': {
                'mean': [0.581,0.554,0.586,0.582],
                'std': []
            },
            '16': {
                'mean': [0.613,0.608,0.604,0.603],
                'std': []
            },

            '32': {
                'mean': [0.488,0.506,0.494,0.498],
                'std': []
            },
            '64': {
                'mean': [0.576,0.579,0.578,0.577],
                'std': []
            }
    },
    
    'albert-xxlarge': {
            '8': {
                'mean': [0.572, 0.463, 0.527, 0.601],
                'std': []
            },
            '16': {
                'mean': [0.568, 0.593, 0.573, 0.546],
                'std': []
            },

            '32': {
                'mean': [0.532, 0.525, 0.52, 0.502],
                'std': []
            },
            '64': {
                'mean': [0.56307339, 0.566513, 0.549694, 0.544266],
                'std': []
            }
    }
    

}


data_a = [data['albert-base']['8']['mean'], 
             data['albert-base']['16']['mean'], 
             data['albert-base']['32']['mean'], 
             data['albert-base']['64']['mean'], 
            ]

data_b = [data['bert-base']['8']['mean'], 
             data['bert-base']['16']['mean'], 
             data['bert-base']['32']['mean'], 
             data['bert-base']['64']['mean'], 
            ]


data_c = [data['albert-xxlarge']['8']['mean'], 
             data['albert-xxlarge']['16']['mean'], 
             data['albert-xxlarge']['32']['mean'], 
             data['albert-xxlarge']['64']['mean'], 
            ]

plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.4, ymax=0.65)
