# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from matplotlib.transforms import Affine2D

import warnings
warnings.filterwarnings('ignore')

# %%
def plot_hyperparams(dev32, cv, mdl, title=''):
    fig, (ax0, ax1, ax2, ax3) = plt.subplots(ncols=4, sharey=True, figsize=(30,8))
    hp=0

    trans1 = Affine2D().translate(0.0, 0.0) + ax0.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax0.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax0.transData
    er1 = ax0.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax0.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax0.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
    ax0.set_title("HP1")
    ax0.set_xlabel('# shots')
    # ax0.legend(loc="upper right")
    # plt.show()
    ax0.grid()


    hp=1
    trans1 = Affine2D().translate(0.0, 0.0) + ax1.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax1.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax1.transData
    er1 = ax1.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax1.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax1.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
#     ax1.set_title(f"{TASK}, HP2")
    ax1.set_title("HP2")
    ax1.set_xlabel('# shots')
    # ax1.legend(loc="upper right")
    # plt.show()
    ax1.grid()

    hp=2
    trans1 = Affine2D().translate(0.0, 0.0) + ax2.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax2.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax2.transData
    er1 = ax2.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax2.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax2.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
    ax2.set_title("HP3")
    ax2.set_xlabel('# shots')
    # ax2.legend(loc="upper right")
    # plt.show()
    ax2.grid()

    hp=3
    trans1 = Affine2D().translate(0.0, 0.0) + ax3.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax3.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax3.transData
    er1 = ax3.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax3.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax3.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
    ax3.set_title("HP4")
    ax3.legend(loc="lower left")
    ax3.set_xlabel('# shots')

    # plt.show()ac
    ax3.grid()
    fig = plt.gcf()
    fig.suptitle(title, fontsize=30)
    return

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)
    return

def plot_bar(data_a, data_b, data_c, ymin=0.4, ymax=0.6):
    ticks = ['8', '16', '32', '64']
    
    plt.figure(figsize=(8,5))

    bpc = plt.boxplot(data_a, positions=np.array(range(len(data_a)))*2.0, widths=0.4)
    bpl = plt.boxplot(data_b, positions=np.array(range(len(data_b)))*2.0-0.45, widths=0.4)
    bpr = plt.boxplot(data_c, positions=np.array(range(len(data_c)))*2.0+0.45, widths=0.4)
    set_box_color(bpc, 'b')
    set_box_color(bpl, 'r')
    set_box_color(bpr, 'g')

    plt.plot([], c='b', label='multisplit')
    plt.plot([], c='r', label='cv')
    plt.plot([], c='g', label='mdl')

    plt.legend(loc='lower right')

    plt.xticks(range(0, len(ticks) * 2, 2), ticks)
    plt.xlim(-2, len(ticks)*2)
    plt.ylim(ymin, ymax)
    plt.tight_layout()
    plt.grid()
    plt.title(f"{TASK}")
    plt.xlabel('# shots')
    return

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)
    return

def plot_bar_models(data_a, label_a, data_b, label_b, data_c, label_c, ymin=0.4, ymax=0.6):
    ticks = ['8', '16', '32', '64']
    
    plt.figure(figsize=(8,5))

    bpl = plt.boxplot(data_a, positions=np.array(range(len(data_b)))*2.0-0.45, widths=0.4)
    bpc = plt.boxplot(data_b, positions=np.array(range(len(data_a)))*2.0, widths=0.4)
    bpr = plt.boxplot(data_c, positions=np.array(range(len(data_c)))*2.0+0.45, widths=0.4)
    set_box_color(bpl, 'b')
    set_box_color(bpc, 'r')
    set_box_color(bpr, 'g')

#     plt.plot([], c='b', label='bert-base')
#     plt.plot([], c='r', label='albert-base')
#     plt.plot([], c='g', label='albert-xxlarge')

    plt.plot([], c='b', label=label_a)
    plt.plot([], c='r', label=label_b)
    plt.plot([], c='g', label=label_c)

    plt.legend(loc='lower right')

    plt.xticks(range(0, len(ticks) * 2, 2), ticks)
    plt.xlim(-2, len(ticks)*2)
    plt.ylim(ymin, ymax)
    plt.tight_layout()
    plt.grid()
    plt.title(f"{TASK}")
    plt.xlabel('# shots')
    return

# %%
# RTE
# Albert-xxlarge-v2

TITLE='task=RTE, metric=accuracy, model=Albert-xxlarge-v2'

# plt.figure(figsize=(10,10))
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
        [0.5505, 0.5162, 0.533, 0.51083],
        [0.5171, 0.5342, 0.515, 0.504512],
        [0.5181, 0.493, 0.498, 0.526173],
        [0.4981, 0.5, 0.517, 0.553249]
    ],
    'std': [
        [0.0356,0.05156,0.041,0.0264467],
        [0.0475,0.0451,0.042,0.01297],
        [0.03614,0.0207,0.074,0.05987],
        [0.03716,0.042,0.059,0.04747],
           ]
}

cv = {
        'mean': [
        [0.5171, 0.5144, 0.5478, 0.545126],
        [0.5063, 0.5397, 0.5306, 0.52166],
        [0.4756, 0.4981, 0.4918, 0.511732],
        [0.5054, 0.5505, 0.499, 0.513537],    
        ],
    'std': [
        [0.0812,0.0168,0.09813,0.056314],
        [0.0619,0.0209,0.0492,0.053749],
        [0.0382,0.0448,0.0595,0.047196],
        [0.0504,0.0544,0.0323,0.03925],
           ]
}

mdl = {
    'mean': [
        [0.493, 0.503, 0.511, 0.516245],
        [0.486, 0.523, 0.511, 0.519855],
        [0.476, 0.47, 0.541, 0.52707],
        [0.461, 0.502, 0.513, 0.492779]
    ],
    
    'std': [
        [0.058,0.034,0.0669,0.02166],
        [0.015,0.047,0.0018,0.03487],
        [0.054,0.038,0.062,0.03006],
        [0.023,0.027,0.038,0.032087]
    ]
}

plot_hyperparams(dev32, cv, mdl, TITLE)

# %%
# RTE
# Albert-base-v2

TITLE='task=RTE, metric=accuracy, model=Albert-base-v2'

# plt.figure(figsize=(10,10))
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
        [0.498, 0.515, 0.481, 0.485],
[0.509, 0.512, 0.488, 0.479],
[0.495, 0.497, 0.484, 0.5],
[0.505, 0.502, 0.494, 0.499]
    ],
    'std': [
        [0.0284,0.02609,0.0245,0.016],
[0.0495,0.0222,0.015,0.025],
[0.0284,0.0209,0.0162,0.027],
[0.0449,0.0217,0.0222,0.021]
           ]
}

cv = {
        'mean': [
            [0.489, 0.495, 0.488, 0.486],
[0.484, 0.501, 0.477, 0.49],
[0.521, 0.513, 0.488, 0.486],
[0.511, 0.503, 0.478, 0.498]
        ],
    'std': [
        [0.0309,0.0122,0.018,0.01],
[0.0151,0.011,0.018,0.03],
[0.0356,0.028,0.028,0.009],
[0.0296,0.0085,0.0254,0.016]
           ]
}

mdl = {
    'mean': [
        [0.477, 0.524, 0.498, 0.479],
[0.485, 0.522, 0.494, 0.468],
[0.472, 0.537, 0.503, 0.457],
[0.479, 0.526, 0.497, 0.463]
    ],
    
    'std': [
        [0.009,0.012,0.025,0.024],
[0.018,0.027,0.027,0.013],
[0.012,0.014,0.009,0.011],
[0.114,0.02,0.012,0.011]
    ]
}

plot_hyperparams(dev32, cv, mdl, TITLE)

# %%
# RTE
# bert-base-v2

TITLE='task=RTE, metric=accuracy, model=bert-base-v2'

# plt.figure(figsize=(10,10))
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
        [0.506, 0.52, 0.502, 0.48],
[0.5, 0.525, 0.5, 0.481],
[0.529, 0.503, 0.516, 0.479],
[0.502, 0.513, 0.516, 0.473]
    ],
    'std': [
        [0.047,0.032,0.033,0.038],
[0.038,0.0301,0.026,0.036],
[0.018,0.035,0.027,0.014],
[0.0305,0.0205,0.028,0.013]
           ]
}

cv = {
        'mean': [
            [0.482, 0.531, 0.505, 0.493],
[0.478, 0.522, 0.5, 0.493],
[0.483, 0.519, 0.504, 0.532],
[0.475, 0.525, 0.509, 0.518]
        ],
    'std': [
        [0.016,0.039,0.024,0.036],
[0.0075,0.041,0.031,0.037],
[0.019,0.035,0.0129,0.0419],
[0.0085,0.038,0.0045,0.0401]
           ]
}

mdl = {
    'mean': [
        [0.477, 0.518, 0.522, 0.509],
[0.473, 0.523, 0.518, 0.509],
[0.493, 0.5009, 0.523, 0.501],
[0.482, 0.489, 0.518, 0.513]
    ],
    
    'std': [
        [0.014,0.025,0.013,0.042],
[0.0074,0.036,0.019,0.036],
[0.0223,0.029,0.012,0.053],
[0.018,0.017,0.011,0.046]
    ]
}

plot_hyperparams(dev32, cv, mdl, TITLE)

# %%
#RTE
# Albert-xxlarge-v2

# TASK = 'RTE, accuracy mean value'
TASK = 'RTE, metric=accuracy mean value, model=Albert-xxlarge-v2'

matplotlib.rcParams.update({'font.size':15})


data = {
    'dev32': {
            '8': {
                'mean': [0.5505, 0.5171, 0.5181, 0.4981],
                'std': [0.0356, 0.0475, 0.03614, 0.03716]
            },
            '16': {
                'mean': [0.5162, 0.5342, 0.493, 0.5],
                'std': [0.05156, 0.0451, 0.0207, 0.042]
            },

            '32': {
                'mean': [0.533, 0.515, 0.498, 0.517],
                'std': [0.041, 0.042, 0.074, 0.059]
            },
            '64': {
                'mean': [0.51083, 0.504512, 0.526173, 0.553249],
                'std': [0.0264467, 0.01297, 0.05987, 0.04747]
            }
    },
    
    'cv': {
            '8': {
                'mean': [0.5171, 0.5063, 0.4756, 0.5054],
                'std': [0.0812, 0.0619, 0.0382, 0.0504]
            },
            '16': {
                'mean': [0.5144, 0.5397, 0.4981, 0.5505],
                'std': [0.0168, 0.0209, 0.0448, 0.0544]
            },

            '32': {
                'mean': [0.5478, 0.5306, 0.4918, 0.499],
                'std': [0.09813, 0.0492, 0.0595, 0.0323]
            },
            '64': {
                'mean': [0.545126, 0.52166, 0.511732, 0.513537],
                'std': [0.056314, 0.053749, 0.047196, 0.03925]
            }
    },
    
    'mdl': {
            '8': {
                'mean': [0.493, 0.486, 0.476, 0.461],
                'std': [0.058, 0.015, 0.054, 0.023]
            },
            '16': {
                'mean': [0.503, 0.523, 0.47, 0.502],
                'std': [0.034, 0.047, 0.038, 0.027]
            },

            '32': {
                'mean': [0.511, 0.511, 0.541, 0.513],
                'std': [0.0669, 0.0018, 0.062, 0.038]
            },
            '64': {
                'mean': [0.516245, 0.519855, 0.52707, 0.492779],
                'std': [0.02166, 0.03487, 0.03006, 0.032087]
            }
    }
    

}


data_a = [data['dev32']['8']['mean'], 
             data['dev32']['16']['mean'], 
             data['dev32']['32']['mean'], 
             data['dev32']['64']['mean'], 
            ]

data_b = [data['cv']['8']['mean'], 
             data['cv']['16']['mean'], 
             data['cv']['32']['mean'], 
             data['cv']['64']['mean'], 
            ]

data_c = [data['mdl']['8']['mean'], 
             data['mdl']['16']['mean'], 
             data['mdl']['32']['mean'], 
             data['mdl']['64']['mean'], 
            ]

plot_bar(data_a, data_b, data_c, ymin=.4, ymax=0.65)

# %%
# TASK = "RTE, accuracy standard deviation"
TASK = 'RTE, metric=accuracy standard deviation, model=Albert-xxlarge-v2'

data_a = [data['dev32']['8']['std'], 
             data['dev32']['16']['std'], 
             data['dev32']['32']['std'], 
             data['dev32']['64']['std'], 
            ]

data_b = [data['cv']['8']['std'], 
             data['cv']['16']['std'], 
             data['cv']['32']['std'], 
             data['cv']['64']['std'], 
            ]

data_c = [data['mdl']['8']['std'], 
             data['mdl']['16']['std'], 
             data['mdl']['32']['std'], 
             data['mdl']['64']['std'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0, ymax=0.1)

# %%
#RTE
# Albert-xxlarge-v2

# TASK = 'RTE, accuracy mean value'
TASK = 'RTE, metric=accuracy mean value, model=Albert-base-v2'

matplotlib.rcParams.update({'font.size':15})


data = {
    'dev32': {
            '8': {
                'mean': [0.498, 0.509, 0.495, 0.505],
                'std': []
            },
            '16': {
                'mean': [0.515, 0.512, 0.497, 0.502],
                'std': []
            },

            '32': {
                'mean': [0.481,0.488,0.484,0.494],
                'std': []
            },
            '64': {
                'mean': [0.485,0.479,0.5,0.499],
                'std': []
            }
    },
    
    'cv': {
            '8': {
                'mean': [0.489,0.484,0.521,0.511],
                'std': []
            },
            '16': {
                'mean': [0.495,0.501,0.513,0.503],
                'std': []
            },

            '32': {
                'mean': [0.488,0.477,0.488,0.478],
                'std': []
            },
            '64': {
                'mean': [0.486,0.49,0.486,0.498],
                'std': []
            }
    },
    
    'mdl': {
            '8': {
                'mean': [0.477,0.485,0.472,0.479],
                'std': []
            },
            '16': {
                'mean': [0.524,0.522,0.537,0.526],
                'std': []
            },

            '32': {
                'mean': [0.498,0.494,0.503,0.497],
                'std': []
            },
            '64': {
                'mean': [0.479,0.468,0.457,0.463],
                'std': []
            }
    }
    

}


data_a = [data['dev32']['8']['mean'], 
             data['dev32']['16']['mean'], 
             data['dev32']['32']['mean'], 
             data['dev32']['64']['mean'], 
            ]

data_b = [data['cv']['8']['mean'], 
             data['cv']['16']['mean'], 
             data['cv']['32']['mean'], 
             data['cv']['64']['mean'], 
            ]

data_c = [data['mdl']['8']['mean'], 
             data['mdl']['16']['mean'], 
             data['mdl']['32']['mean'], 
             data['mdl']['64']['mean'], 
            ]

plot_bar(data_a, data_b, data_c, ymin=.4, ymax=0.65)

# %%
#RTE
# Albert-xxlarge-v2

# TASK = 'RTE, accuracy mean value'
TASK = 'RTE, metric=accuracy mean value, model=bert-base-v2'

matplotlib.rcParams.update({'font.size':15})


data = {
    'dev32': {
            '8': {
                'mean': [0.506, 0.5, 0.529, 0.502],
                'std': []
            },
            '16': {
                'mean': [0.52, 0.525, 0.503, 0.513],
                'std': []
            },

            '32': {
                'mean': [0.502, 0.5, 0.516, 0.516],
                'std': []
            },
            '64': {
                'mean': [0.48, 0.481, 0.479, 0.473],
                'std': []
            }
    },
    
    'cv': {
            '8': {
                'mean': [0.482,0.478,0.483,0.475],
                'std': []
            },
            '16': {
                'mean': [0.531,0.522,0.519,0.525],
                'std': []
            },

            '32': {
                'mean': [0.505,0.5,0.504,0.509],
                'std': []
            },
            '64': {
                'mean': [0.493,0.493,0.532,0.518],
                'std': []
            }
    },
    
    'mdl': {
            '8': {
                'mean': [0.477,0.473,0.493,0.482],
                'std': []
            },
            '16': {
                'mean': [0.518,0.523,0.5009,0.489],
                'std': []
            },

            '32': {
                'mean': [0.522,0.518,0.523,0.518],
                'std': []
            },
            '64': {
                'mean': [0.509,0.509,0.501,0.513],
                'std': []
            }
    }
    

}


data_a = [data['dev32']['8']['mean'], 
             data['dev32']['16']['mean'], 
             data['dev32']['32']['mean'], 
             data['dev32']['64']['mean'], 
            ]

data_b = [data['cv']['8']['mean'], 
             data['cv']['16']['mean'], 
             data['cv']['32']['mean'], 
             data['cv']['64']['mean'], 
            ]

data_c = [data['mdl']['8']['mean'], 
             data['mdl']['16']['mean'], 
             data['mdl']['32']['mean'], 
             data['mdl']['64']['mean'], 
            ]

plot_bar(data_a, data_b, data_c, ymin=.4, ymax=0.65)

# %%
#RTE
# dev32 - All models

TASK = 'RTE, metric=accuracy mean value, method=multisplit'

matplotlib.rcParams.update({'font.size':15})


data = {
    'bert-base': {
            '8': {
                'mean': [0.506, 0.5, 0.529, 0.502],
                'std': []
            },
            '16': {
                'mean': [0.52, 0.525, 0.503, 0.513],
                'std': []
            },

            '32': {
                'mean': [0.502, 0.5, 0.516, 0.516],
                'std': []
            },
            '64': {
                'mean': [0.48, 0.481, 0.479, 0.473],
                'std': []
            }
    },
    
    'albert-base': {
            '8': {
                'mean': [0.498, 0.509, 0.495, 0.505],
                'std': []
            },
            '16': {
                'mean': [0.515, 0.512, 0.497, 0.502],
                'std': []
            },

            '32': {
                'mean': [0.481,0.488,0.484,0.494],
                'std': []
            },
            '64': {
                'mean': [0.485,0.479,0.5,0.499],
                'std': []
            }
    },
    
    'albert-xxlarge': {
            '8': {
                'mean': [0.5505, 0.5171, 0.5181, 0.4981],
                'std': []
            },
            '16': {
                'mean': [0.5162, 0.5342, 0.493, 0.5],
                'std': []
            },

            '32': {
                'mean': [0.533, 0.515, 0.498, 0.517],
                'std': []
            },
            '64': {
                'mean': [0.51083, 0.504512, 0.526173, 0.553249],
                'std': []
            }
    }
    

}

data_b = [data['bert-base']['8']['mean'], 
             data['bert-base']['16']['mean'], 
             data['bert-base']['32']['mean'], 
             data['bert-base']['64']['mean'], 
            ]

data_a = [data['albert-base']['8']['mean'], 
             data['albert-base']['16']['mean'], 
             data['albert-base']['32']['mean'], 
             data['albert-base']['64']['mean'], 
            ]

data_c = [data['albert-xxlarge']['8']['mean'], 
             data['albert-xxlarge']['16']['mean'], 
             data['albert-xxlarge']['32']['mean'], 
             data['albert-xxlarge']['64']['mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=.4, ymax=0.65)

plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.4, ymax=0.65)

# %%
# RTE
# cv - All models

# TASK = 'BoolQ, accuracy mean value'
TASK = 'RTE, metric=accuracy mean value, method=cross validation'

matplotlib.rcParams.update({'font.size':15})


data = {
    'bert-base': {
            '8': {
                'mean': [0.482,0.478,0.483,0.475],
                'std': []
            },
            '16': {
                'mean': [0.531,0.522,0.519,0.525],
                'std': []
            },

            '32': {
                'mean': [0.505,0.5,0.504,0.509],
                'std': []
            },
            '64': {
                'mean': [0.493,0.493,0.532,0.518],
                'std': []
            }
    },
    
    'albert-base': {
            '8': {
                'mean': [0.489,0.484,0.521,0.511],
                'std': []
            },
            '16': {
                'mean': [0.495,0.501,0.513,0.503],
                'std': []
            },

            '32': {
                'mean': [0.488,0.477,0.488,0.478],
                'std': []
            },
            '64': {
                'mean': [0.486,0.49,0.486,0.498],
                'std': []
            }
    },
    
    'albert-xxlarge': {
            '8': {
                'mean': [0.5171, 0.5063, 0.4756, 0.5054],
                'std': []
            },
            '16': {
                'mean': [0.5144, 0.5397, 0.4981, 0.5505],
                'std': []
            },

            '32': {
                'mean': [0.5478, 0.5306, 0.4918, 0.499],
                'std': []
            },
            '64': {
                'mean': [0.545126, 0.52166, 0.511732, 0.513537],
                'std': []
            }
    }
    

}

data_a = [data['albert-base']['8']['mean'], 
             data['albert-base']['16']['mean'], 
             data['albert-base']['32']['mean'], 
             data['albert-base']['64']['mean'], 
            ]


data_b = [data['bert-base']['8']['mean'], 
             data['bert-base']['16']['mean'], 
             data['bert-base']['32']['mean'], 
             data['bert-base']['64']['mean'], 
            ]


data_c = [data['albert-xxlarge']['8']['mean'], 
             data['albert-xxlarge']['16']['mean'], 
             data['albert-xxlarge']['32']['mean'], 
             data['albert-xxlarge']['64']['mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=.4, ymax=0.65)

plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.4, ymax=0.65)

# %%
#RTE
# mdl - All models

# TASK = 'BoolQ, accuracy mean value'
TASK = 'RTE, metric=accuracy mean value, method=mdl'

matplotlib.rcParams.update({'font.size':15})


data = {
    'bert-base': {
            '8': {
                'mean': [0.477,0.473,0.493,0.482],
                'std': []
            },
            '16': {
                'mean': [0.518,0.523,0.5009,0.489],
                'std': []
            },

            '32': {
                'mean': [0.522,0.518,0.523,0.518],
                'std': []
            },
            '64': {
                'mean': [0.509,0.509,0.501,0.513],
                'std': []
            }
    },
    
    'albert-base': {
            '8': {
                'mean': [0.477,0.485,0.472,0.479],
                'std': []
            },
            '16': {
                'mean': [0.524,0.522,0.537,0.526],
                'std': []
            },

            '32': {
                'mean': [0.498,0.494,0.503,0.497],
                'std': []
            },
            '64': {
                'mean': [0.479,0.468,0.457,0.463],
                'std': []
            }
    },
    
    'albert-xxlarge': {
            '8': {
                'mean': [0.493, 0.486, 0.476, 0.461],
                'std': []
            },
            '16': {
                'mean': [0.503, 0.523, 0.47, 0.502],
                'std': []
            },

            '32': {
                'mean': [0.511, 0.511, 0.541, 0.513],
                'std': []
            },
            '64': {
                'mean': [0.516245, 0.519855, 0.52707, 0.492779],
                'std': []
            }
    }
    

}


data_a = [data['albert-base']['8']['mean'], 
             data['albert-base']['16']['mean'], 
             data['albert-base']['32']['mean'], 
             data['albert-base']['64']['mean'], 
            ]


data_b = [data['bert-base']['8']['mean'], 
             data['bert-base']['16']['mean'], 
             data['bert-base']['32']['mean'], 
             data['bert-base']['64']['mean'], 
            ]


data_c = [data['albert-xxlarge']['8']['mean'], 
             data['albert-xxlarge']['16']['mean'], 
             data['albert-xxlarge']['32']['mean'], 
             data['albert-xxlarge']['64']['mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=.4, ymax=0.65)
plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.4, ymax=0.65)
