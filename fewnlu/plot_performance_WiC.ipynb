# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from matplotlib.transforms import Affine2D

import warnings
warnings.filterwarnings('ignore')

# %%
def plot_hyperparams(dev32, cv, mdl, title=''):
    fig, (ax0, ax1, ax2, ax3) = plt.subplots(ncols=4, sharey=True, figsize=(30,8))
    hp=0

    trans1 = Affine2D().translate(0.0, 0.0) + ax0.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax0.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax0.transData
    er1 = ax0.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax0.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax0.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
    ax0.set_title("HP1")
    ax0.set_xlabel('# shots')
    # ax0.legend(loc="upper right")
    # plt.show()
    ax0.grid()


    hp=1
    trans1 = Affine2D().translate(0.0, 0.0) + ax1.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax1.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax1.transData
    er1 = ax1.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax1.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax1.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
#     ax1.set_title(f"{TASK}, HP2")
    ax1.set_title("HP2")
    ax1.set_xlabel('# shots')
    # ax1.legend(loc="upper right")
    # plt.show()
    ax1.grid()

    hp=2
    trans1 = Affine2D().translate(0.0, 0.0) + ax2.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax2.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax2.transData
    er1 = ax2.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax2.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax2.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
    ax2.set_title("HP3")
    ax2.set_xlabel('# shots')
    # ax2.legend(loc="upper right")
    # plt.show()
    ax2.grid()

    hp=3
    trans1 = Affine2D().translate(0.0, 0.0) + ax3.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax3.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax3.transData
    er1 = ax3.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax3.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax3.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
    ax3.set_title("HP4")
    ax3.legend(loc="lower left")
    ax3.set_xlabel('# shots')

    # plt.show()ac
    ax3.grid()
    fig = plt.gcf()
    fig.suptitle(title, fontsize=30)
    return

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)
    return

def plot_bar(data_a, data_b, data_c, ymin=0.4, ymax=0.6):
    ticks = ['8', '16', '32', '64']
    
    plt.figure(figsize=(8,5))

    bpc = plt.boxplot(data_a, positions=np.array(range(len(data_a)))*2.0, widths=0.4)
    bpl = plt.boxplot(data_b, positions=np.array(range(len(data_b)))*2.0-0.45, widths=0.4)
    bpr = plt.boxplot(data_c, positions=np.array(range(len(data_c)))*2.0+0.45, widths=0.4)
    set_box_color(bpc, 'b')
    set_box_color(bpl, 'r')
    set_box_color(bpr, 'g')

    plt.plot([], c='b', label='multisplit')
    plt.plot([], c='r', label='cv')
    plt.plot([], c='g', label='mdl')

    plt.legend(loc='lower right')

    plt.xticks(range(0, len(ticks) * 2, 2), ticks)
    plt.xlim(-2, len(ticks)*2)
    plt.ylim(ymin, ymax)
    plt.tight_layout()
    plt.grid()
    plt.title(f"{TASK}")
    plt.xlabel('# shots')
    return

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)
    return

def plot_bar_models(data_a, label_a, data_b, label_b, data_c, label_c, ymin=0.4, ymax=0.6):
    ticks = ['8', '16', '32', '64']
    
    plt.figure(figsize=(8,5))

    bpl = plt.boxplot(data_a, positions=np.array(range(len(data_b)))*2.0-0.45, widths=0.4)
    bpc = plt.boxplot(data_b, positions=np.array(range(len(data_a)))*2.0, widths=0.4)
    bpr = plt.boxplot(data_c, positions=np.array(range(len(data_c)))*2.0+0.45, widths=0.4)
    set_box_color(bpl, 'b')
    set_box_color(bpc, 'r')
    set_box_color(bpr, 'g')

#     plt.plot([], c='b', label='bert-base')
#     plt.plot([], c='r', label='albert-base')
#     plt.plot([], c='g', label='albert-xxlarge')

    plt.plot([], c='b', label=label_a)
    plt.plot([], c='r', label=label_b)
    plt.plot([], c='g', label=label_c)

    plt.legend(loc='lower right')

    plt.xticks(range(0, len(ticks) * 2, 2), ticks)
    plt.xlim(-2, len(ticks)*2)
    plt.ylim(ymin, ymax)
    plt.tight_layout()
    plt.grid()
    plt.title(f"{TASK}")
    plt.xlabel('# shots')
    return

# %%
# WiC
# Albert-xxlarge-v2

# TASK="WiC"
TITLE='task=WiC, metric=accuracy, model=Albert-xxlarge-v2'

# plt.figure(figsize=(10,10))
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
        [0.52155, 0.4764, 0.50156, 0.50744],
        [0.4866, 0.5066, 0.5007, 0.48942],
        [0.51998, 0.5086, 0.5121, 0.5011755],
        [0.4647, 0.4968, 0.4788, 0.539968]
    ],
    'std': [
        [0.04598,0.0338,0.0511,0.03444],
        [0.0413,0.01605,0.01908,0.02],
        [0.04336,0.01972,0.041,0.016947],
        [0.05778,0.00778,0.0332,0.049788]
           ]
}

cv = {
        'mean': [
            [0.5242, 0.4909, 0.5446, 0.52155],
            [0.4917, 0.4839, 0.5152, 0.51528],
            [0.4894, 0.5266, 0.5148, 0.528905],
            [0.4784, 0.5341, 0.5223, 0.53487]
        ],
    'std': [
        [0.023,0.0505,0.0167,0.0288836],
        [0.0135,0.0257,0.0234,0.0499],
        [0.0566,0.0618,0.053,0.041889],
        [0.0528,0.0735,0.0268,0.09613]
           ]
}

mdl = {
    'mean': [
        [0.502, 0.506, 0.525, 0.503526],
        [0.468, 0.511, 0.532, 0.519592],
        [0.471, 0.507, 0.531, 0.538009],
        [0.465, 0.539, 0.544, 0.5113636]
    ],
    
    'std': [
        [0.065,0.028,0.046,0.036318],
        [0.053,0.013,0.034,0.0436345],
        [0.091,0.057,0.032,0.029722],
        [0.055,0.052,0.035,0.03318]
    ]
}



plot_hyperparams(dev32, cv, mdl, TITLE)

# %%
# WiC
# Albert-base-v2

TITLE='task=WiC, metric=accuracy, model=Albert-base-v2'

# plt.figure(figsize=(10,10))
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
        [0.50078, 0.501, 0.523, 0.541],
[0.4988, 0.509, 0.518, 0.537],
[0.521, 0.528, 0.547, 0.545],
[0.525, 0.5289, 0.5419, 0.557]
    ],
    'std': [
        [0.0114,0.0304,0.0245,0.04],
[0.013,0.0304,0.0317,0.047],
[0.0218,0.0353,0.0176,0.048],
[0.0227,0.0393,0.0209,0.033]
           ]
}

cv = {
        'mean': [
            [0.5129, 0.543, 0.525, 0.537],
[0.514, 0.545, 0.527, 0.555],
[0.514, 0.5564, 0.5344, 0.531],
[0.5144, 0.554, 0.53, 0.533]
        ],
    'std': [
        [0.0162,0.0304,0.0133,0.029],
[0.0149,0.0388,0.0095,0.02],
[0.0155,0.0307,0.0267,0.024],
[0.0136,0.04412,0.033,0.025]
           ]
}

mdl = {
    'mean': [
        [0.505, 0.524, 0.535, 0.531],
[0.5, 0.53, 0.539, 0.524],
[0.523, 0.562, 0.549, 0.542],
[0.518, 0.557, 0.557, 0.531]
    ],
    
    'std': [
        [0.026,0.026,0.015,0.022],
[0.013,0.015,0.0092,0.029],
[0.024,0.025,0.007,0.035],
[0.032,0.016,0.005,0.022]
    ]
}



plot_hyperparams(dev32, cv, mdl, TITLE)

# %%
# WiC
# bert-base-v2

TITLE='task=WiC, metric=accuracy, model=bert-base-v2'

# plt.figure(figsize=(10,10))
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
        [0.501, 0.524, 0.536, 0.539],
[0.5, 0.521, 0.531, 0.548],
[0.481, 0.449, 0.45, 0.531],
[0.495, 0.449, 0.453, 0.532]
    ],
    'std': [
        [0.0039,0.0556,0.062,0.056],
[0.006,0.035,0.057,0.053],
[0.027,0.05,0.0051,0.047],
[0.0074,0.054,0.0038,0.041]
           ]
}

cv = {
        'mean': [
            [0.513, 0.545, 0.518, 0.506],
[0.515, 0.545, 0.527, 0.505],
[0.488, 0.439, 0.509, 0.52],
[0.494, 0.44, 0.521, 0.518]
        ],
    'std': [
        [0.042,0.077,0.069,0.062],
[0.039,0.072,0.0491,0.059],
[0.015,0.014,0.052,0.066],
[0.01,0.015,0.047,0.059]
           ]
}

mdl = {
    'mean': [
        [0.482, 0.515, 0.532, 0.49],
[0.49, 0.53, 0.528, 0.498],
[0.43, 0.437, 0.51, 0.548],
[0.445, 0.44, 0.506, 0.547]
    ],
    
    'std': [
        [0.0778,0.091,0.062,0.057],
[0.06,0.084,0.062,0.0509],
[0.05,0.02,0.074,0.069],
[0.044,0.025,0.074,0.064]
    ]
}



plot_hyperparams(dev32, cv, mdl, TITLE)

# %%
#WiC
# Albert-xxlarge-v2

# TASK = 'WiC, accuracy mean value'
TASK='WiC, metric=accuracy mean value, model=Albert-xxlarge-v2'

matplotlib.rcParams.update({'font.size':12})

data = {
    'dev32': {
            '8': {
                'mean': [0.52155, 0.4866, 0.51998, 0.4647],
                'std': [0.04598, 0.0413, 0.04336, 0.05778]
            },
            '16': {
                'mean': [0.4764, 0.5066, 0.5086, 0.4968],
                'std': [0.0338, 0.01605, 0.01972, 0.00778]
            },

            '32': {
                'mean': [0.50156, 0.5007, 0.5121, 0.4788],
                'std': [0.0511, 0.01908, 0.041, 0.0332]
            },
            '64': {
                'mean': [0.50744, 0.48942, 0.5011755, 0.539968],
                'std': [0.03444, 0.02, 0.016947, 0.049788]
            }
    },
    
    'cv': {
            '8': {
                'mean': [0.5242, 0.4917, 0.4894, 0.4784],
                'std': []
            },
            '16': {
                'mean': [0.4909, 0.4839, 0.5266, 0.5341],
                'std': []
            },

            '32': {
                'mean': [0.5446, 0.5152, 0.5148, 0.5223],
                'std': []
            },
            '64': {
                'mean': [0.52155, 0.51528, 0.528905, 0.53487],
                'std': []
            }
    },
    
    'mdl': {
            '8': {
                'mean': [0.502, 0.468, 0.471, 0.465],
                'std': []
            },
            '16': {
                'mean': [0.506, 0.511, 0.507, 0.539],
                'std': []
            },

            '32': {
                'mean': [0.525, 0.532, 0.531, 0.544],
                'std': []
            },
            '64': {
                'mean': [0.503526, 0.519592, 0.538009, 0.5113636],
                'std': []
            }
    }
    

}


data_a = [data['dev32']['8']['mean'], 
             data['dev32']['16']['mean'], 
             data['dev32']['32']['mean'], 
             data['dev32']['64']['mean'], 
            ]

data_b = [data['cv']['8']['mean'], 
             data['cv']['16']['mean'], 
             data['cv']['32']['mean'], 
             data['cv']['64']['mean'], 
            ]

data_c = [data['mdl']['8']['mean'], 
             data['mdl']['16']['mean'], 
             data['mdl']['32']['mean'], 
             data['mdl']['64']['mean'], 
            ]

plot_bar(data_a, data_b, data_c, ymin=.4, ymax=0.6)

# %%
# TASK = "WiC, accuracy standard deviation"
# TASK='WiC, metric=accuracy standard deviation, model=Albert-xxlarge-v2'

# data_a = [data['dev32']['8']['std'], 
#              data['dev32']['16']['std'], 
#              data['dev32']['32']['std'], 
#              data['dev32']['64']['std'], 
#             ]

# data_b = [data['cv']['8']['std'], 
#              data['cv']['16']['std'], 
#              data['cv']['32']['std'], 
#              data['cv']['64']['std'], 
#             ]

# data_c = [data['mdl']['8']['std'], 
#              data['mdl']['16']['std'], 
#              data['mdl']['32']['std'], 
#              data['mdl']['64']['std'], 
#             ]


# plot_bar(data_a, data_b, data_c, ymin=0.4, ymax=0.6)

# %%
#WiC
# Albert-base-v2

TASK='WiC, metric=accuracy mean value, model=Albert-base-v2'

matplotlib.rcParams.update({'font.size':12})

data = {
    'dev32': {
            '8': {
                'mean': [0.50078, 0.4988, 0.521, 0.525],
                'std': []
            },
            '16': {
                'mean': [0.501, 0.509, 0.528, 0.5289],
                'std': []
            },

            '32': {
                'mean': [0.523,0.518,0.547,0.5419],
                'std': []
            },
            '64': {
                'mean': [0.541,0.537,0.545,0.557],
                'std': []
            }
    },
    
    'cv': {
            '8': {
                'mean': [0.5129,0.514,0.514,0.5144],
                'std': []
            },
            '16': {
                'mean': [0.543,0.545,0.5564,0.554],
                'std': []
            },

            '32': {
                'mean': [0.525,0.527,0.5344,0.53],
                'std': []
            },
            '64': {
                'mean': [0.537,0.555,0.531,0.533],
                'std': []
            }
    },
    
    'mdl': {
            '8': {
                'mean': [0.505,0.5,0.523,0.518],
                'std': []
            },
            '16': {
                'mean': [0.524,0.53,0.562,0.557],
                'std': []
            },

            '32': {
                'mean': [0.535,0.539,0.549,0.557],
                'std': []
            },
            '64': {
                'mean': [0.531,0.524,0.542,0.531],
                'std': []
            }
    }
    

}


data_a = [data['dev32']['8']['mean'], 
             data['dev32']['16']['mean'], 
             data['dev32']['32']['mean'], 
             data['dev32']['64']['mean'], 
            ]

data_b = [data['cv']['8']['mean'], 
             data['cv']['16']['mean'], 
             data['cv']['32']['mean'], 
             data['cv']['64']['mean'], 
            ]

data_c = [data['mdl']['8']['mean'], 
             data['mdl']['16']['mean'], 
             data['mdl']['32']['mean'], 
             data['mdl']['64']['mean'], 
            ]

plot_bar(data_a, data_b, data_c, ymin=.4, ymax=0.6)

# %%
#WiC
# bert-base-v2

TASK='WiC, metric=accuracy mean value, model=bert-base-v2'

matplotlib.rcParams.update({'font.size':12})

data = {
    'dev32': {
            '8': {
                'mean': [0.501, 0.5, 0.481, 0.495],
                'std': []
            },
            '16': {
                'mean': [0.524, 0.521, 0.449, 0.449],
                'std': []
            },

            '32': {
                'mean': [0.536, 0.531, 0.45, 0.453],
                'std': []
            },
            '64': {
                'mean': [0.539, 0.548, 0.531, 0.532],
                'std': []
            }
    },
    
    'cv': {
            '8': {
                'mean': [0.513,0.515,0.488,0.494],
                'std': []
            },
            '16': {
                'mean': [0.545,0.545,0.439,0.44],
                'std': []
            },

            '32': {
                'mean': [0.518,0.527,0.509,0.521],
                'std': []
            },
            '64': {
                'mean': [0.506,0.505,0.52,0.518],
                'std': []
            }
    },
    
    'mdl': {
            '8': {
                'mean': [0.482,0.49,0.43,0.445],
                'std': []
            },
            '16': {
                'mean': [0.515,0.53,0.437,0.44],
                'std': []
            },

            '32': {
                'mean': [0.532,0.528,0.51,0.506],
                'std': []
            },
            '64': {
                'mean': [0.49,0.498,0.548,0.547],
                'std': []
            }
    }
    

}


data_a = [data['dev32']['8']['mean'], 
             data['dev32']['16']['mean'], 
             data['dev32']['32']['mean'], 
             data['dev32']['64']['mean'], 
            ]

data_b = [data['cv']['8']['mean'], 
             data['cv']['16']['mean'], 
             data['cv']['32']['mean'], 
             data['cv']['64']['mean'], 
            ]

data_c = [data['mdl']['8']['mean'], 
             data['mdl']['16']['mean'], 
             data['mdl']['32']['mean'], 
             data['mdl']['64']['mean'], 
            ]

plot_bar(data_a, data_b, data_c, ymin=.4, ymax=0.6)

# %%
#WiC
# dev32 - All models

TASK = 'WiC, metric=accuracy mean value, method=multisplit'

matplotlib.rcParams.update({'font.size':15})


data = {
    'bert-base': {
            '8': {
                'mean': [0.501, 0.5, 0.481, 0.495],
                'std': []
            },
            '16': {
                'mean': [0.524, 0.521, 0.449, 0.449],
                'std': []
            },

            '32': {
                'mean': [0.536, 0.531, 0.45, 0.453],
                'std': []
            },
            '64': {
                'mean': [0.539, 0.548, 0.531, 0.532],
                'std': []
            }
    },
    
    'albert-base': {
            '8': {
                'mean': [0.50078, 0.4988, 0.521, 0.525],
                'std': []
            },
            '16': {
                'mean': [0.501, 0.509, 0.528, 0.5289],
                'std': []
            },

            '32': {
                'mean': [0.523,0.518,0.547,0.5419],
                'std': []
            },
            '64': {
                'mean': [0.541,0.537,0.545,0.557],
                'std': []
            }
    },
    
    'albert-xxlarge': {
            '8': {
                'mean': [0.52155, 0.4866, 0.51998, 0.4647],
                'std': []
            },
            '16': {
                'mean': [0.4764, 0.5066, 0.5086, 0.4968],
                'std': []
            },

            '32': {
                'mean': [0.50156, 0.5007, 0.5121, 0.4788],
                'std': []
            },
            '64': {
                'mean': [0.50744, 0.48942, 0.5011755, 0.539968],
                'std': []
            }
    }
    

}

data_b = [data['bert-base']['8']['mean'], 
             data['bert-base']['16']['mean'], 
             data['bert-base']['32']['mean'], 
             data['bert-base']['64']['mean'], 
            ]

data_a = [data['albert-base']['8']['mean'], 
             data['albert-base']['16']['mean'], 
             data['albert-base']['32']['mean'], 
             data['albert-base']['64']['mean'], 
            ]

data_c = [data['albert-xxlarge']['8']['mean'], 
             data['albert-xxlarge']['16']['mean'], 
             data['albert-xxlarge']['32']['mean'], 
             data['albert-xxlarge']['64']['mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=.4, ymax=0.65)
plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.35, ymax=0.6)

# %%
#WiC
# CV - All models

TASK = 'WiC, metric=accuracy mean value, method=cross validation'

matplotlib.rcParams.update({'font.size':15})


data = {
    'bert-base': {
            '8': {
                'mean': [0.513,0.515,0.488,0.494],
                'std': []
            },
            '16': {
                'mean': [0.545,0.545,0.439,0.44],
                'std': []
            },

            '32': {
                'mean': [0.518,0.527,0.509,0.521],
                'std': []
            },
            '64': {
                'mean': [0.506,0.505,0.52,0.518],
                'std': []
            }
    },
    
    'albert-base': {
            '8': {
                'mean': [0.5129,0.514,0.514,0.5144],
                'std': []
            },
            '16': {
                'mean': [0.543,0.545,0.5564,0.554],
                'std': []
            },

            '32': {
                'mean': [0.525,0.527,0.5344,0.53],
                'std': []
            },
            '64': {
                'mean': [0.537,0.555,0.531,0.533],
                'std': []
            }
    },
    
    'albert-xxlarge': {
            '8': {
                'mean': [0.5242, 0.4917, 0.4894, 0.4784],
                'std': []
            },
            '16': {
                'mean': [0.4909, 0.4839, 0.5266, 0.5341],
                'std': []
            },

            '32': {
                'mean': [0.5446, 0.5152, 0.5148, 0.5223],
                'std': []
            },
            '64': {
                'mean': [0.52155, 0.51528, 0.528905, 0.53487],
                'std': []
            }
    }
    

}

data_b = [data['bert-base']['8']['mean'], 
             data['bert-base']['16']['mean'], 
             data['bert-base']['32']['mean'], 
             data['bert-base']['64']['mean'], 
            ]

data_a = [data['albert-base']['8']['mean'], 
             data['albert-base']['16']['mean'], 
             data['albert-base']['32']['mean'], 
             data['albert-base']['64']['mean'], 
            ]

data_c = [data['albert-xxlarge']['8']['mean'], 
             data['albert-xxlarge']['16']['mean'], 
             data['albert-xxlarge']['32']['mean'], 
             data['albert-xxlarge']['64']['mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=.4, ymax=0.65)

plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.35, ymax=0.6)

# %%
#WiC
# mdl - All models

TASK = 'WiC, metric=accuracy mean value, method=mdl'

matplotlib.rcParams.update({'font.size':15})


data = {
    'bert-base': {
            '8': {
                'mean': [0.482,0.49,0.43,0.445],
                'std': []
            },
            '16': {
                'mean': [0.515,0.53,0.437,0.44],
                'std': []
            },

            '32': {
                'mean': [0.532,0.528,0.51,0.506],
                'std': []
            },
            '64': {
                'mean': [0.49,0.498,0.548,0.547],
                'std': []
            }
    },
    
    'albert-base': {
            '8': {
                'mean': [0.505,0.5,0.523,0.518],
                'std': []
            },
            '16': {
                'mean': [0.524,0.53,0.562,0.557],
                'std': []
            },

            '32': {
                'mean': [0.535,0.539,0.549,0.557],
                'std': []
            },
            '64': {
                'mean': [0.531,0.524,0.542,0.531],
                'std': []
            }
    },
    
    'albert-xxlarge': {
            '8': {
                'mean': [0.502, 0.468, 0.471, 0.465],
                'std': []
            },
            '16': {
                'mean': [0.506, 0.511, 0.507, 0.539],
                'std': []
            },

            '32': {
                'mean': [0.525, 0.532, 0.531, 0.544],
                'std': []
            },
            '64': {
                'mean': [0.503526, 0.519592, 0.538009, 0.5113636],
                'std': []
            }
    }
    

}

data_b = [data['bert-base']['8']['mean'], 
             data['bert-base']['16']['mean'], 
             data['bert-base']['32']['mean'], 
             data['bert-base']['64']['mean'], 
            ]

data_a = [data['albert-base']['8']['mean'], 
             data['albert-base']['16']['mean'], 
             data['albert-base']['32']['mean'], 
             data['albert-base']['64']['mean'], 
            ]

data_c = [data['albert-xxlarge']['8']['mean'], 
             data['albert-xxlarge']['16']['mean'], 
             data['albert-xxlarge']['32']['mean'], 
             data['albert-xxlarge']['64']['mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=.4, ymax=0.65)

plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.35, ymax=0.6)
