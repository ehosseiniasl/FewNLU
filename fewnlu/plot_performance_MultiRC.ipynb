# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from matplotlib.transforms import Affine2D

import warnings
warnings.filterwarnings('ignore')

# %%
def plot_hyperparams(dev32, cv, mdl, title=''):
    fig, (ax0, ax1, ax2, ax3) = plt.subplots(ncols=4, sharey=True, figsize=(30,8))
    hp=0

    trans1 = Affine2D().translate(0.0, 0.0) + ax0.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax0.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax0.transData
    er1 = ax0.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax0.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax0.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
    ax0.set_title("HP1")
    ax0.set_xlabel('# shots')
    # ax0.legend(loc="upper right")
    # plt.show()
    ax0.grid()


    hp=1
    trans1 = Affine2D().translate(0.0, 0.0) + ax1.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax1.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax1.transData
    er1 = ax1.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax1.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax1.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
#     ax1.set_title(f"{TASK}, HP2")
    ax1.set_title("HP2")
    ax1.set_xlabel('# shots')
    # ax1.legend(loc="upper right")
    # plt.show()
    ax1.grid()

    hp=2
    trans1 = Affine2D().translate(0.0, 0.0) + ax2.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax2.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax2.transData
    er1 = ax2.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax2.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax2.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
    ax2.set_title("HP3")
    ax2.set_xlabel('# shots')
    # ax2.legend(loc="upper right")
    # plt.show()
    ax2.grid()

    hp=3
    trans1 = Affine2D().translate(0.0, 0.0) + ax3.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax3.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax3.transData
    er1 = ax3.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax3.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax3.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
    ax3.set_title("HP4")
    ax3.legend(loc="lower left")
    ax3.set_xlabel('# shots')

    # plt.show()ac
    ax3.grid()
    fig = plt.gcf()
    fig.suptitle(title, fontsize=30)
    return

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)
    return

def plot_bar(data_a, data_b, data_c, ymin=0.4, ymax=0.6):
    ticks = ['8', '16', '32', '64']
    
    plt.figure(figsize=(8,5))

    bpc = plt.boxplot(data_a, positions=np.array(range(len(data_a)))*2.0, widths=0.4)
    bpl = plt.boxplot(data_b, positions=np.array(range(len(data_b)))*2.0-0.45, widths=0.4)
    bpr = plt.boxplot(data_c, positions=np.array(range(len(data_c)))*2.0+0.45, widths=0.4)
    set_box_color(bpc, 'b')
    set_box_color(bpl, 'r')
    set_box_color(bpr, 'g')

    plt.plot([], c='b', label='multisplit')
    plt.plot([], c='r', label='cv')
    plt.plot([], c='g', label='mdl')

    plt.legend(loc='lower right')

    plt.xticks(range(0, len(ticks) * 2, 2), ticks)
    plt.xlim(-2, len(ticks)*2)
    plt.ylim(ymin, ymax)
    plt.tight_layout()
    plt.grid()
    plt.title(f"{TASK}")
    plt.xlabel('# shots')
    return

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)
    return

def plot_bar_models(data_a, label_a, data_b, label_b, data_c, label_c, ymin=0.4, ymax=0.6):
    ticks = ['8', '16', '32', '64']
    
    plt.figure(figsize=(8,5))

    bpl = plt.boxplot(data_a, positions=np.array(range(len(data_b)))*2.0-0.45, widths=0.4)
    bpc = plt.boxplot(data_b, positions=np.array(range(len(data_a)))*2.0, widths=0.4)
    bpr = plt.boxplot(data_c, positions=np.array(range(len(data_c)))*2.0+0.45, widths=0.4)
    set_box_color(bpl, 'b')
    set_box_color(bpc, 'r')
    set_box_color(bpr, 'g')

#     plt.plot([], c='b', label='bert-base')
#     plt.plot([], c='r', label='albert-base')
#     plt.plot([], c='g', label='albert-xxlarge')

    plt.plot([], c='b', label=label_a)
    plt.plot([], c='r', label=label_b)
    plt.plot([], c='g', label=label_c)

    plt.legend(loc='lower right')

    plt.xticks(range(0, len(ticks) * 2, 2), ticks)
    plt.xlim(-2, len(ticks)*2)
    plt.ylim(ymin, ymax)
    plt.tight_layout()
    plt.grid()
    plt.title(f"{TASK}")
    plt.xlabel('# shots')
    return

# %%
# MultiRC
# Albert-xxlarge-v2

TITLE='task=MultiRC, metric=accuracy, model=Albert-xxlarge-v2'

# plt.figure(figsize=(10,10))
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
        [0.54, 0.558, 0.583, 0.5965],
        [0.59, 0.584, 0.623, 0.66955],
        [0.535, 0.548, 0.594, 0.6579],
        [0.55, 0.578, 0.628, 0.65155]
    ],
    'std': [
        [0.012,0.022,0.036,0.08031],
        [0.022,0.034,0.039,0.0172],
        [0.051,0.049,0.032,0.0744],
        [0.066,0.052,0.009,0.035401]
           ]
}

cv = {
        'mean': [
            [0.562, 0.574, 0.558, 0.68201],
            [0.594, 0.609, 0.637, 0.668213],
            [0.582, 0.591, 0.613, 0.6798],
            [0.535, 0.599, 0.639, 0.6916]
        ],
    'std': [
        [0.008,0.027,0.072,0.00769],
        [0.036,0.013,0.036,0.08659],
        [0.024,0.029,0.0326,0.03877],
        [0.074,0.0419,0.053,0.01651]
           ]
}

mdl = {
    'mean': [
        [0.552, 0.569, 0.617, 0.6585],
        [0.551, 0.562, 0.655, 0.6379],
        [0.549, 0.546, 0.593, 0.6659],
        [0.601, 0.572, 0.629, 0.6812]
    ],
    
    'std': [
        [0.025,0.013,0.045,0.0426],
        [0.017,0.067,0.015,0.0581],
        [0.024,0.057,0.012,0.0466],
        [0.023,0.025,0.031,0.07488]
    ]
}


plot_hyperparams(dev32, cv, mdl, TITLE)

# %%
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

TASK = 'task=MultiRC, metric=F1 score, model=Albert-xxlarge-v2'

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
        [0.54, 0.446, 0.423, 0.5589],
        [0.56, 0.49, 0.362, 0.528734],
        [0.507, 0.469, 0.349, 0.59045],
        [0.417, 0.541, 0.456, 0.5095]
    ],
    'std': [
        [0.03, 0.089, 0.061, 0.06789],
        [0.068, 0.075, 0.16, 0.093757],
        [0.057, 0.067, 0.113, 0.0744],
        [0.186, 0.0907, 0.12, 0.1755]
           ]
}

cv = {
        'mean': [
            [0.364, 0.434, 0.519, 0.6353],
            [0.411, 0.404, 0.445, 0.4851],
            [0.357, 0.457, 0.48, 0.5721],
            [0.5599, 0.313, 0.467, 0.6093]
        ],
    'std': [
        [0.06, 0.096, 0.048, 0.041415],
        [0.13, 0.128, 0.103, 0.2329],
        [0.138, 0.06, 0.076, 0.0726],
        [0.062, 0.156, 0.195, 0.03025]
           ]
}

mdl = {
    'mean': [
        [0.445, 0.404, 0.5, 0.5618],
        [0.351, 0.485, 0.53, 0.5884],
        [0.427, 0.419, 0.461, 0.5858],
        [0.445, 0.528, 0.451, 0.4837]
    ],
    
    'std': [
        [0.0921, 0.117, 0.122, 0.0967],
        [0.088, 0.09, 0.066, 0.0482],
        [0.086, 0.162, 0.0508, 0.1169],
        [0.166, 0.039, 0.157, 0.327]
    ]
}


plot_hyperparams(dev32, cv, mdl, TASK)

# %%
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

TASK = 'task=MultiRC, metric=EM, model=Albert-xxlarge-v2'

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
        [0.071, 0.052, 0.076, 0.101259],
        [0.091, 0.0705, 0.071, 0.141658],
        [0.0553, 0.058, 0.059, 0.14533],
        [0.0516, 0.0729, 0.094, 0.103095]
    ],
    'std': [
        [0.012, 0.013, 0.035, 0.06041],
        [0.014, 0.012, 0.03, 0.04322],
        [0.018, 0.027, 0.0206, 0.0319],
        [0.042, 0.016, 0.021, 0.05255]
           ]
}

cv = {
        'mean': [
            [0.05, 0.0605, 0.0716, 0.16815],
            [0.07, 0.068, 0.084, 0.1411],
            [0.053, 0.0813, 0.083, 0.16107],
            [0.065, 0.0608, 0.096, 0.1681]
        ],
    'std': [
        [0.017, 0.022, 0.029, 0.02178],
        [0.024, 0.0203, 0.025, 0.1051],
        [0.032, 0.026, 0.017, 0.0495],
        [0.034, 0.052, 0.056, 0.0243]
           ]
}

mdl = {
    'mean': [
        [0.0584, 0.064, 0.11, 0.1345],
        [0.0403, 0.068, 0.098, 0.1251],
        [0.057, 0.04, 0.083, 0.1513],
        [0.068, 0.067, 0.076, 0.1518]
    ],
    
    'std': [
        [0.02, 0.025, 0.056, 0.0454],
        [0.006, 0.049, 0.016, 0.0483],
        [0.014, 0.032, 0.0087, 0.0597],
        [0.032, 0.0064, 0.027, 0.105]
    ]
}


plot_hyperparams(dev32, cv, mdl, TASK)

# %%
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

TASK = 'task=MultiRC, metric=accuracy, model=Albert-base-v2'

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
[0.561, 0.571, 0.599, 0.61],
[0.561, 0.573, 0.592, 0.619],
[0.566, 0.575, 0.612, 0.611],
[0.573, 0.566, 0.609, 0.622]
    ],
    'std': [
[0.0105,0.028,0.027,0.014],
[0.017,0.021,0.033,0.02],
[0.026,0.0157,0.024,0.012],
[0.0195,0.023,0.032,0.016]
           ]
}

cv = {
        'mean': [
[0.575, 0.577, 0.598, 0.629],
[0.587, 0.569, 0.601, 0.625],
[0.582, 0.575, 0.61, 0.639],
[0.586, 0.574, 0.598, 0.621]
        ],
    'std': [
[0.0098,0.014,0.0165,0.026],
[0.0029,0.021,0.018,0.0089],
[0.028,0.0027,0.0103,0.014],
[0.033,0.019,0.025,0.0084]
           ]
}

mdl = {
    'mean': [
[0.586, 0.572, 0.622, 0.622],
[0.596, 0.567, 0.637, 0.641],
[0.587, 0.563, 0.62, 0.636],
[0.589, 0.551, 0.62, 0.621]
    ],
    
    'std': [
[0.012,0.0168,0.018,0.016],
[0.0128,0.031,0.012,0.012],
[0.013,0.014,0.0081,0.007],
[0.0082,0.022,0.0076,0.017]
    ]
}


plot_hyperparams(dev32, cv, mdl, TASK)

# %%
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

TASK = 'task=MultiRC, metric=F1 score, model=Albert-base-v2'

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
[0.479, 0.543, 0.439, 0.525],
[0.5, 0.547, 0.44, 0.529],
[0.487, 0.544, 0.521, 0.522],
[0.53, 0.539, 0.502, 0.548]
    ],
    'std': [
[0.095, 0.041, 0.102, 0.033],
[0.091, 0.026, 0.11, 0.052],
[0.0716, 0.017, 0.0955, 0.045],
[0.039, 0.046, 0.128, 0.037]
           ]
}

cv = {
        'mean': [
[0.489, 0.553, 0.598, 0.541],
[0.465, 0.539, 0.471, 0.534],
[0.441, 0.564, 0.484, 0.514],
[0.548, 0.55, 0.482, 0.505]
        ],
    'std': [
[0.049, 0.023, 0.078, 0.046],
[0.103, 0.031, 0.0446, 0.039],
[0.12, 0.029, 0.07, 0.02],
[0.0528, 0.021, 0.086, 0.028]
           ]
}

mdl = {
    'mean': [
[0.475, 0.577, 0.571, 0.522],
[0.454, 0.587, 0.55, 0.57],
[0.493, 0.574, 0.574, 0.523],
[0.499, 0.591, 0.529, 0.536]
    ],
    
    'std': [
[0.039, 0.011, 0.045, 0.042],
[0.011, 0.0082, 0.05, 0.048],
[0.068, 0.025, 0.014, 0.041],
[0.096, 0.0099, 0.032, 0.064]
    ]
}


plot_hyperparams(dev32, cv, mdl, TASK)

# %%
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

TASK = 'task=MultiRC, metric=EM, model=Albert-base-v2'

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
[0.044, 0.059, 0.072, 0.09],
[0.061, 0.058, 0.072, 0.086],
[0.0529, 0.0598, 0.0839, 0.086],
[0.0616, 0.059, 0.079, 0.098]
    ],
    'std': [
[0.0086, 0.019, 0.021, 0.0089],
[0.008, 0.015, 0.028, 0.024],
[0.0094, 0.018, 0.0266, 0.014],
[0.012, 0.009, 0.032, 0.013]
           ]
}

cv = {
        'mean': [
[0.06, 0.07, 0.07, 0.099],
[0.07, 0.056, 0.0729, 0.091],
[0.058, 0.064, 0.071, 0.094],
[0.076, 0.065, 0.0779, 0.092]
            
        ],
    'std': [
[0.009, 0.011, 0.014, 0.015],
[0.031, 0.0107, 0.0114, 0.0084],
[0.024, 0.006, 0.016, 0.0064],
[0.021, 0.0098, 0.02, 0.014]
           ]
}

mdl = {
    'mean': [
[0.06, 0.056, 0.093, 0.102],
[0.056, 0.057, 0.094, 0.117],
[0.058, 0.057, 0.095, 0.108],
[0.058, 0.054, 0.087, 0.103]
    ],
    
    'std': [
[0.01, 0.011, 0.01, 0.016],
[0.011, 0.018, 0.011, 0.018],
[0.014, 0.0082, 0.0044, 0.017],
[0.011, 0.015, 0.015, 0.021]
    ]
}


plot_hyperparams(dev32, cv, mdl, TASK)

# %%
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

TASK = 'task=MultiRC, metric=accuracy, model=bert-base'

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
[0.523, 0.559, 0.599, 0.612],
[0.532, 0.577, 0.596, 0.623],
[0.52, 0.55, 0.594, 0.614],
[0.507, 0.577, 0.596, 0.623]
    ],
    'std': [
[0.042,0.042,0.017,0.0071],
[0.043,0.035,0.022,0.0033],
[0.07,0.026,0.032,0.0078],
[0.055,0.033,0.018,0.0069]
           ]
}

cv = {
        'mean': [
[0.559, 0.539, 0.614, 0.614],
[0.573, 0.56, 0.625, 0.619],
[0.535, 0.554, 0.599, 0.615],
[0.557, 0.57, 0.614, 0.61]
        ],
    'std': [
[0.037,0.015,0.011,0.002],
[0.023,0.02,0.086,0.0035],
[0.031,0.033,0.025,0.013],
[0.014,0.018,0.019,0.02]
           ]
}

mdl = {
    'mean': [
[0.561, 0.559, 0.602, 0.606],
[0.551, 0.586, 0.606, 0.615],
[0.561, 0.567, 0.61, 0.615],
[0.532, 0.561, 0.609, 0.612]
    ],
    
    'std': [
[0.027,0.019,0.013,0.019],
[0.035,0.023,0.017,0.0077],
[0.033,0.022,0.0045,0.0026],
[0.032,0.026,0.007,0.0075]
    ]
}


plot_hyperparams(dev32, cv, mdl, TASK)

# %%
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

TASK = 'task=MultiRC, metric=F1 score, model=bert-base'

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
[0.599, 0.587, 0.508, 0.53],
[0.594, 0.588, 0.52, 0.489],
[0.58, 0.594, 0.47, 0.535],
[0.592, 0.583, 0.472, 0.53]
    ],
    'std': [
[0.014, 0.023, 0.021, 0.052],
[0.019, 0.034, 0.032, 0.065],
[0.039, 0.016, 0.12, 0.022],
[0.0081, 0.013, 0.12, 0.036]
           ]
}

cv = {
        'mean': [
[0.566, 0.467, 0.553, 0.575],
[0.538, 0.503, 0.524, 0.563],
[0.553, 0.586, 0.507, 0.543],
[0.524, 0.568, 0.517, 0.536]
        ],
    'std': [
[0.015, 0.125, 0.024, 0.01],
[0.062, 0.15, 0.025, 0.019],
[0.095, 0.011, 0.046, 0.017],
[0.12, 0.025, 0.033, 0.027]
           ]
}

mdl = {
    'mean': [
[0.301, 0.594, 0.56, 0.541],
[0.353, 0.565, 0.551, 0.542],
[0.352, 0.581, 0.559, 0.546],
[0.43, 0.588, 0.551, 0.544]
    ],
    
    'std': [
[0.18, 0.0041, 0.029, 0.021],
[0.139, 0.04, 0.048, 0.035],
[0.227, 0.025, 0.01, 0.016],
[0.173, 0.027, 0.026, 0.0054]
    ]
}


plot_hyperparams(dev32, cv, mdl, TASK)

# %%
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

TASK = 'task=MultiRC, metric=EM, model=bert-base'

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
[0.057, 0.059, 0.076, 0.082],
[0.054, 0.069, 0.077, 0.08],
[0.049, 0.063, 0.064, 0.0865],
[0.05, 0.062, 0.068, 0.083]
    ],
    'std': [
[0.012, 0.013, 0.006, 0.0052],
[0.0085, 0.011, 0.0068, 0.0075],
[0.015, 0.0039, 0.027, 0.016],
[0.017, 0.01, 0.024, 0.01]
           ]
}

cv = {
        'mean': [
[0.064, 0.048, 0.085, 0.095],
[0.065, 0.064, 0.086, 0.099],
[0.062, 0.064, 0.071, 0.089],
[0.063, 0.066, 0.083, 0.085]
        ],
    'std': [
[0.013, 0.0097, 0.021, 0.0052],
[0.0088, 0.01, 0.012, 0.0086],
[0.0092, 0.006, 0.018, 0.0061],
[0.0071, 0.0044, 0.012, 0.0024]
           ]
}

mdl = {
    'mean': [
[0.036, 0.063, 0.078, 0.086],
[0.039, 0.068, 0.084, 0.092],
[0.036, 0.068, 0.0899, 0.096],
[0.041, 0.065, 0.09, 0.086]
    ],
    
    'std': [
[0.026, 0.011, 0.0056, 0.016],
[0.02, 0.0088, 0.01, 0.017],
[0.024, 0.0086, 0.009, 0.0077],
[0.025, 0.012, 0.014, 0.011]
    ]
}


plot_hyperparams(dev32, cv, mdl, TASK)

# %%
# MultiRC
# Albert-xxlarge-v2

TASK = 'MultiRC, metric=accuracy mean value, model=Albert-xxlarge-v2'

matplotlib.rcParams.update({'font.size':15})

data = {
    'dev32': {
            '8': {
                'mean': [0.54, 0.59, 0.535, 0.55],
                'std': []
            },
            '16': {
                'mean': [0.558, 0.584, 0.548, 0.578],
                'std': []
            },

            '32': {
                'mean': [0.583, 0.623, 0.594, 0.628],
                'std': []
            },
            '64': {
                'mean': [0.5965, 0.66955, 0.6579, 0.65155],
                'std': []
            }
    },
    
    'cv': {
            '8': {
                'mean': [0.562, 0.594, 0.582, 0.535],
                'std': []
            },
            '16': {
                'mean': [0.574, 0.609, 0.591, 0.599],
                'std': []
            },

            '32': {
                'mean': [0.558, 0.637, 0.613, 0.639],
                'std': []
            },
            '64': {
                'mean': [0.68201, 0.668213, 0.6798, 0.6916],
                'std': []
            }
    },
    
    'mdl': {
            '8': {
                'mean': [0.552, 0.551, 0.549, 0.601],
                'std': []
            },
            '16': {
                'mean': [0.569, 0.562, 0.546, 0.572],
                'std': []
            },

            '32': {
                'mean': [0.617, 0.655, 0.593, 0.629],
                'std': []
            },
            '64': {
                'mean': [0.6585, 0.6379, 0.6659, 0.6812],
                'std': []
            }
    }
    

}

    

data_a = [data['dev32']['8']['mean'], 
             data['dev32']['16']['mean'], 
             data['dev32']['32']['mean'], 
             data['dev32']['64']['mean'], 
            ]

data_b = [data['cv']['8']['mean'], 
             data['cv']['16']['mean'], 
             data['cv']['32']['mean'], 
             data['cv']['64']['mean'], 
            ]

data_c = [data['mdl']['8']['mean'], 
             data['mdl']['16']['mean'], 
             data['mdl']['32']['mean'], 
             data['mdl']['64']['mean'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0.4, ymax=0.8)

# %%
# MultiRC F1 
# Albert-xxlarge-v2

TASK = 'MultiRC, metric=f1 mean value, model=Albert-xxlarge-v2'

data = {
    'dev32': {
            '8': {
                'mean': [0.54, 0.56, 0.507, 0.417],
                'std': []
            },
            '16': {
                'mean': [0.446, 0.49, 0.469, 0.541],
                'std': []
            },

            '32': {
                'mean': [0.423, 0.362, 0.349, 0.456],
                'std': []
            },
            '64': {
                'mean': [0.5589, 0.528734, 0.59045, 0.5095],
                'std': []
            }
    },
    
    'cv': {
            '8': {
                'mean': [0.364, 0.411, 0.357, 0.5599],
                'std': []
            },
            '16': {
                'mean': [0.434, 0.404, 0.457, 0.313],
                'std': []
            },

            '32': {
                'mean': [0.519, 0.445,0.48, 0.467],
                'std': []
            },
            '64': {
                'mean': [0.6353, 0.4851, 0.5721, 0.6093],
                'std': []
            }
    },
    
    'mdl': {
            '8': {
                'mean': [0.445, 0.351, 0.427, 0.445],
                'std': []
            },
            '16': {
                'mean': [0.404, 0.485, 0.419, 0.528],
                'std': []
            },

            '32': {
                'mean': [0.5, 0.53, 0.461, 0.451],
                'std': []
            },
            '64': {
                'mean': [0.5618, 0.5884, 0.5858, 0.4837],
                'std': []
            }
    }
    
}


data_a = [data['dev32']['8']['mean'], 
             data['dev32']['16']['mean'], 
             data['dev32']['32']['mean'], 
             data['dev32']['64']['mean'], 
            ]

data_b = [data['cv']['8']['mean'], 
             data['cv']['16']['mean'], 
             data['cv']['32']['mean'], 
             data['cv']['64']['mean'], 
            ]

data_c = [data['mdl']['8']['mean'], 
             data['mdl']['16']['mean'], 
             data['mdl']['32']['mean'], 
             data['mdl']['64']['mean'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0.25, ymax=0.7)

# %%
# MultiRC EM 
# Albert-xxlarge-v2

TASK = 'MultiRC, metric=EM mean value, model=Albert-xxlarge-v2'



data = {
    'dev32': {
            '8': {
                'mean': [0.071, 0.091, 0.0553, 0.0516],
            },
            '16': {
                'mean': [0.052, 0.0705, 0.058, 0.0729],
            },

            '32': {
                'mean': [0.076, 0.071, 0.059, 0.094],
            },
            '64': {
                'mean': [0.101259, 0.141658, 0.14533, 0.103095],
                'std': []
            }
    },
    
    'cv': {
            '8': {
                'mean': [0.05, 0.07, 0.053, 0.065],
                'std': []
            },
            '16': {
                'mean': [0.0605, 0.068, 0.0813, 0.0608],
                'std': []
            },

            '32': {
                'mean': [0.0716, 0.084, 0.083, 0.096],
                'std': []
            },
            '64': {
                'mean': [0.0716, 0.084, 0.083, 0.096],
                'std': []
            }
    },
    
    'mdl': {
            '8': {
                'mean': [0.0584, 0.0403, 0.057, 0.068],
                'std': []
            },
            '16': {
                'mean': [0.064, 0.068, 0.04, 0.067],
                'std': []
            },

            '32': {
                'mean': [0.11, 0.098, 0.083, 0.076],
                'std': []
            },
            '64': {
                'mean': [0.1345, 0.1251, 0.1513, 0.1518],
                'std': []
            }
    }
    

}

data_a = [data['dev32']['8']['mean'], 
             data['dev32']['16']['mean'], 
             data['dev32']['32']['mean'], 
             data['dev32']['64']['mean'], 
            ]

data_b = [data['cv']['8']['mean'], 
             data['cv']['16']['mean'], 
             data['cv']['32']['mean'], 
             data['cv']['64']['mean'], 
            ]

data_c = [data['mdl']['8']['mean'], 
             data['mdl']['16']['mean'], 
             data['mdl']['32']['mean'], 
             data['mdl']['64']['mean'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0.01, ymax=0.2)

# %%
# MultiRC
# Albert-xxlarge-v2

TASK = 'MultiRC, metric=accuracy mean value, model=Albert-base-v2'

matplotlib.rcParams.update({'font.size':15})

data = {
    'albert-xxlarge':
    {
        'dev32': {
            '8': {
                'mean': [0.54, 0.59, 0.535, 0.55],
                'f1_mean': [0.54,0.59,0.535,0.55],
                'em_mean': [0.071,0.091,0.0553,0.0516]
            },
            '16': {
                'mean': [0.558, 0.584, 0.548, 0.578],
                'f1_mean': [0.446,0.49,0.469,0.541],
                'em_mean': [0.052,0.0705,0.058,0.0729]
            },

            '32': {
                'mean': [0.583, 0.623, 0.594, 0.628],
                'f1_mean': [0.423,0.362,0.349,0.456],
                'em_mean': [0.076,0.071,0.059,0.094]
            },
            '64': {
                'mean': [0.5965, 0.66955, 0.6579, 0.65155],
                'f1_mean': [0.5589,0.528734,0.59045,0.5095],
                'em_mean': [0.101259,0.141658,0.14533,0.103095]
            }
    },
    
    'cv': {
            '8': {
                'mean': [0.562, 0.594, 0.582, 0.535],
                'f1_mean': [0.364,0.411,0.357,0.5599],
                'em_mean': [0.05,0.07,0.053,0.065]
            },
            '16': {
                'mean': [0.574, 0.609, 0.591, 0.599],
                'f1_mean': [0.434,0.404,0.457,0.313],
                'em_mean': [0.0605,0.068,0.0813,0.0608]
            },

            '32': {
                'mean': [0.558, 0.637, 0.613, 0.639],
                'f1_mean': [0.519,0.445,0.48,0.467],
                'em_mean': [0.0716,0.084,0.083,0.096]
            },
            '64': {
                'mean': [0.68201, 0.668213, 0.6798, 0.6916],
                'f1_mean': [0.6353,0.4851,0.5721,0.6093],
                'em_mean': [0.0716,0.084,0.083,0.096]
            }
    },
    
    'mdl': {
            '8': {
                'mean': [0.552, 0.551, 0.549, 0.601],
                'f1_mean': [0.445,0.351,0.427,0.445],
                'em_mean': [0.0584,0.0403,0.057,0.068]
            },
            '16': {
                'mean': [0.569, 0.562, 0.546, 0.572],
                'f1_mean': [0.404,0.485,0.419,0.528],
                'em_mean': [0.064,0.068,0.04,0.067]
            },

            '32': {
                'mean': [0.617, 0.655, 0.593, 0.629],
                'f1_mean': [0.5,0.53,0.461,0.451],
                'em_mean': [0.11,0.098,0.083,0.076]
            },
            '64': {
                'mean': [0.6585, 0.6379, 0.6659, 0.6812],
                'f1_mean': [0.5618,0.5884,0.5858,0.4837],
                'em_mean': [0.1345,0.1251,0.1513,0.1518]
            }
    }
    
    },
    'albert-base': {
        'dev32': {
                '8': {
                    'mean': [0.561,0.561,0.566,0.573],
                    'f1_mean': [0.479,0.5,0.487,0.53],
                    'em_mean': [0.044,0.061,0.0529,0.0616]
                },
                '16': {
                    'mean': [0.571,0.573,0.575,0.566],
                    'f1_mean': [0.543,0.547,0.544,0.539],
                    'em_mean': [0.059,0.058,0.0598,0.059]
                },

                '32': {
                    'mean': [0.599,0.592,0.612,0.609],
                    'f1_mean': [0.439,0.44,0.521,0.502],
                    'em_mean': [0.072,0.072,0.0839,0.079]
                },
                '64': {
                    'mean': [0.61,0.619,0.611,0.622],
                    'f1_mean': [0.525,0.529,0.522,0.548],
                    'em_mean': [0.09,0.086,0.086,0.098]
                }
        },

        'cv': {
                '8': {
                    'mean': [0.575,0.587,0.582,0.586],
                    'f1_mean': [0.489,0.465,0.441,0.548],
                    'em_mean': [0.06,0.07,0.058,0.076]
                },
                '16': {
                    'mean': [0.577,0.569,0.575,0.574],
                    'f1_mean': [0.553,0.539,0.564,0.55],
                    'em_mean': [0.07,0.056,0.064,0.065]
                },

                '32': {
                    'mean': [0.598,0.601,0.61,0.598],
                    'f1_mean': [0.598,0.471,0.484,0.482],
                    'em_mean': [0.07,0.0729,0.071,0.0779]
                },
                '64': {
                    'mean': [0.629,0.625,0.639,0.621],
                    'f1_mean': [0.541,0.534,0.514,0.505],
                    'em_mean': [0.099,0.091,0.094,0.092]
                }
        },

        'mdl': {
                '8': {
                    'mean': [0.586,0.596,0.587,0.589],
                    'f1_mean': [0.475,0.454,0.493,0.499],
                    'em_mean': [0.06,0.056,0.058,0.058]
                },
                '16': {
                    'mean': [0.572,0.567,0.563,0.551],
                    'f1_mean': [0.577,0.587,0.574,0.591],
                    'em_mean': [0.056,0.057,0.057,0.054]
                },

                '32': {
                    'mean': [0.622,0.637,0.62,0.62],
                    'f1_mean': [0.571,0.55,0.574,0.529],
                    'em_mean': [0.093,0.094,0.095,0.087]
                },
                '64': {
                    'mean': [0.622,0.641,0.636,0.621],
                    'f1_mean': [0.522,0.57,0.523,0.536],
                    'em_mean': [0.102,0.117,0.108,0.103]
                }
        }
    },
    
    'bert-base':
        {
         'dev32': {
                '8': {
                    'mean': [0.523,0.532,0.52,0.507],
                    'f1_mean': [0.599,0.594,0.58,0.592],
                    'em_mean': [0.057,0.054,0.049,0.05]
                },
                '16': {
                    'mean': [0.559,0.577,0.55,0.577],
                    'f1_mean': [0.587,0.588,0.594,0.583],
                    'em_mean': [0.059,0.069,0.063,0.062]
                },

                '32': {
                    'mean': [0.599,0.596,0.594,0.596],
                    'f1_mean': [0.508,0.52,0.47,0.472],
                    'em_mean': [0.076,0.077,0.064,0.068]
                },
                '64': {
                    'mean': [0.612,0.623,0.614,0.623],
                    'f1_mean': [0.53,0.489,0.535,0.53],
                    'em_mean': [0.082,0.08,0.0865,0.083]
                }
        },

        'cv': {
                '8': {
                    'mean': [0.559,0.573,0.535,0.557],
                    'f1_mean': [0.566,0.538,0.553,0.524],
                    'em_mean': [0.064,0.065,0.062,0.063]
                },
                '16': {
                    'mean': [0.539,0.56,0.554,0.57],
                    'f1_mean': [0.467,0.503,0.586,0.568],
                    'em_mean': [0.048,0.064,0.064,0.066]
                },

                '32': {
                    'mean': [0.614,0.625,0.599,0.614],
                    'f1_mean': [0.553,0.524,0.507,0.517],
                    'em_mean': [0.085,0.086,0.071,0.083]
                },
                '64': {
                    'mean': [0.614,0.619,0.615,0.61],
                    'f1_mean': [0.575,0.563,0.543,0.536],
                    'em_mean': [0.095,0.099,0.089,0.085]
                }
        },

        'mdl': {
                '8': {
                    'mean': [0.561,0.551,0.561,0.532],
                    'f1_mean': [0.301,0.353,0.352,0.43],
                    'em_mean': [0.036,0.039,0.036,0.041]
                },
                '16': {
                    'mean': [0.559,0.586,0.567,0.561],
                    'f1_mean': [0.594,0.565,0.581,0.588],
                    'em_mean': [0.063,0.068,0.068,0.065]
                },

                '32': {
                    'mean': [0.602,0.606,0.61,0.609],
                    'f1_mean': [0.56,0.551,0.559,0.551],
                    'em_mean': [0.078,0.084,0.0899,0.09]
                },
                '64': {
                    'mean': [0.606,0.615,0.615,0.612],
                    'f1_mean': [0.541,0.542,0.546,0.544],
                    'em_mean': [0.086,0.092,0.096,0.086]
                }
        }   
    }
}

    

data_a = [data['albert-base']['dev32']['8']['mean'], 
             data['albert-base']['dev32']['16']['mean'], 
             data['albert-base']['dev32']['32']['mean'], 
             data['albert-base']['dev32']['64']['mean'], 
            ]

data_b = [data['albert-base']['cv']['8']['mean'], 
             data['albert-base']['cv']['16']['mean'], 
             data['albert-base']['cv']['32']['mean'], 
             data['albert-base']['cv']['64']['mean'], 
            ]

data_c = [data['albert-base']['mdl']['8']['mean'], 
             data['albert-base']['mdl']['16']['mean'], 
             data['albert-base']['mdl']['32']['mean'], 
             data['albert-base']['mdl']['64']['mean'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0.4, ymax=0.8)

# %%
TASK = 'MultiRC, metric=f1 mean value, model=Albert-base-v2'

matplotlib.rcParams.update({'font.size':15})


data_a = [data['albert-base']['dev32']['8']['f1_mean'], 
             data['albert-base']['dev32']['16']['f1_mean'], 
             data['albert-base']['dev32']['32']['f1_mean'], 
             data['albert-base']['dev32']['64']['f1_mean'], 
            ]

data_b = [data['albert-base']['cv']['8']['f1_mean'], 
             data['albert-base']['cv']['16']['f1_mean'], 
             data['albert-base']['cv']['32']['f1_mean'], 
             data['albert-base']['cv']['64']['f1_mean'], 
            ]

data_c = [data['albert-base']['mdl']['8']['f1_mean'], 
             data['albert-base']['mdl']['16']['f1_mean'], 
             data['albert-base']['mdl']['32']['f1_mean'], 
             data['albert-base']['mdl']['64']['f1_mean'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0.3, ymax=0.8)

# %%
TASK = 'MultiRC, metric=EM mean value, model=Albert-base-v2'

matplotlib.rcParams.update({'font.size':15})


data_a = [data['albert-base']['dev32']['8']['em_mean'], 
             data['albert-base']['dev32']['16']['em_mean'], 
             data['albert-base']['dev32']['32']['em_mean'], 
             data['albert-base']['dev32']['64']['em_mean'], 
            ]

data_b = [data['albert-base']['cv']['8']['em_mean'], 
             data['albert-base']['cv']['16']['em_mean'], 
             data['albert-base']['cv']['32']['em_mean'], 
             data['albert-base']['cv']['64']['em_mean'], 
            ]

data_c = [data['albert-base']['mdl']['8']['em_mean'], 
             data['albert-base']['mdl']['16']['em_mean'], 
             data['albert-base']['mdl']['32']['em_mean'], 
             data['albert-base']['mdl']['64']['em_mean'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0.0, ymax=0.15)

# %%
TASK = 'MultiRC, metric=accuracy mean value, model=bert-base'

matplotlib.rcParams.update({'font.size':15})


data_a = [data['bert-base']['dev32']['8']['mean'], 
             data['bert-base']['dev32']['16']['mean'], 
             data['bert-base']['dev32']['32']['mean'], 
             data['bert-base']['dev32']['64']['mean'], 
            ]

data_b = [data['bert-base']['cv']['8']['mean'], 
             data['bert-base']['cv']['16']['mean'], 
             data['bert-base']['cv']['32']['mean'], 
             data['bert-base']['cv']['64']['mean'], 
            ]

data_c = [data['bert-base']['mdl']['8']['mean'], 
             data['bert-base']['mdl']['16']['mean'], 
             data['bert-base']['mdl']['32']['mean'], 
             data['bert-base']['mdl']['64']['mean'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0.45, ymax=0.7)

# %%
TASK = 'MultiRC, metric=f1 mean value, model=bert-base'

matplotlib.rcParams.update({'font.size':15})


data_a = [data['bert-base']['dev32']['8']['f1_mean'], 
             data['bert-base']['dev32']['16']['f1_mean'], 
             data['bert-base']['dev32']['32']['f1_mean'], 
             data['bert-base']['dev32']['64']['f1_mean'], 
            ]

data_b = [data['bert-base']['cv']['8']['f1_mean'], 
             data['bert-base']['cv']['16']['f1_mean'], 
             data['bert-base']['cv']['32']['f1_mean'], 
             data['bert-base']['cv']['64']['f1_mean'], 
            ]

data_c = [data['bert-base']['mdl']['8']['f1_mean'], 
             data['bert-base']['mdl']['16']['f1_mean'], 
             data['bert-base']['mdl']['32']['f1_mean'], 
             data['bert-base']['mdl']['64']['f1_mean'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0.2, ymax=0.7)

# %%
TASK = 'MultiRC, metric=EM mean value, model=bert-base'

matplotlib.rcParams.update({'font.size':15})


data_a = [data['bert-base']['dev32']['8']['em_mean'], 
             data['bert-base']['dev32']['16']['em_mean'], 
             data['bert-base']['dev32']['32']['em_mean'], 
             data['bert-base']['dev32']['64']['em_mean'], 
            ]

data_b = [data['bert-base']['cv']['8']['em_mean'], 
             data['bert-base']['cv']['16']['em_mean'], 
             data['bert-base']['cv']['32']['em_mean'], 
             data['bert-base']['cv']['64']['em_mean'], 
            ]

data_c = [data['bert-base']['mdl']['8']['em_mean'], 
             data['bert-base']['mdl']['16']['em_mean'], 
             data['bert-base']['mdl']['32']['em_mean'], 
             data['bert-base']['mdl']['64']['em_mean'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0, ymax=0.15)

# %%
TASK = 'MultiRC, metric=accuracy mean value, method=multisplit'

matplotlib.rcParams.update({'font.size':15})



data_b = [data['bert-base']['dev32']['8']['mean'], 
             data['bert-base']['dev32']['16']['mean'], 
             data['bert-base']['dev32']['32']['mean'], 
             data['bert-base']['dev32']['64']['mean'], 
            ]

data_a = [data['albert-base']['dev32']['8']['mean'], 
             data['albert-base']['dev32']['16']['mean'], 
             data['albert-base']['dev32']['32']['mean'], 
             data['albert-base']['dev32']['64']['mean'], 
            ]

data_c = [data['albert-xxlarge']['dev32']['8']['mean'], 
             data['albert-xxlarge']['dev32']['16']['mean'], 
             data['albert-xxlarge']['dev32']['32']['mean'], 
             data['albert-xxlarge']['dev32']['64']['mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=0.4, ymax=0.8)
plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.4, ymax=0.8)

# %%
TASK = 'MultiRC, metric=accuracy mean value, method=cross validation'

matplotlib.rcParams.update({'font.size':15})



data_b = [data['bert-base']['cv']['8']['mean'], 
             data['bert-base']['cv']['16']['mean'], 
             data['bert-base']['cv']['32']['mean'], 
             data['bert-base']['cv']['64']['mean'], 
            ]

data_a = [data['albert-base']['cv']['8']['mean'], 
             data['albert-base']['cv']['16']['mean'], 
             data['albert-base']['cv']['32']['mean'], 
             data['albert-base']['cv']['64']['mean'], 
            ]

data_c = [data['albert-xxlarge']['cv']['8']['mean'], 
             data['albert-xxlarge']['cv']['16']['mean'], 
             data['albert-xxlarge']['cv']['32']['mean'], 
             data['albert-xxlarge']['cv']['64']['mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=0.4, ymax=0.8)
plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.4, ymax=0.8)

# %%
TASK = 'MultiRC, metric=accuracy mean value, method=mdl'

matplotlib.rcParams.update({'font.size':15})



data_b = [data['bert-base']['mdl']['8']['mean'], 
             data['bert-base']['mdl']['16']['mean'], 
             data['bert-base']['mdl']['32']['mean'], 
             data['bert-base']['mdl']['64']['mean'], 
            ]

data_a = [data['albert-base']['mdl']['8']['mean'], 
             data['albert-base']['mdl']['16']['mean'], 
             data['albert-base']['mdl']['32']['mean'], 
             data['albert-base']['mdl']['64']['mean'], 
            ]

data_c = [data['albert-xxlarge']['mdl']['8']['mean'], 
             data['albert-xxlarge']['mdl']['16']['mean'], 
             data['albert-xxlarge']['mdl']['32']['mean'], 
             data['albert-xxlarge']['mdl']['64']['mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=0.4, ymax=0.8)
plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.4, ymax=0.8)

# %%
TASK = 'MultiRC, metric=f1 mean value, method=multisplit'

matplotlib.rcParams.update({'font.size':15})



data_b = [data['bert-base']['dev32']['8']['f1_mean'], 
             data['bert-base']['dev32']['16']['f1_mean'], 
             data['bert-base']['dev32']['32']['f1_mean'], 
             data['bert-base']['dev32']['64']['f1_mean'], 
            ]

data_a = [data['albert-base']['dev32']['8']['f1_mean'], 
             data['albert-base']['dev32']['16']['f1_mean'], 
             data['albert-base']['dev32']['32']['f1_mean'], 
             data['albert-base']['dev32']['64']['f1_mean'], 
            ]

data_c = [data['albert-xxlarge']['dev32']['8']['f1_mean'], 
             data['albert-xxlarge']['dev32']['16']['f1_mean'], 
             data['albert-xxlarge']['dev32']['32']['f1_mean'], 
             data['albert-xxlarge']['dev32']['64']['f1_mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=0.2, ymax=0.7)
plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.2, ymax=0.7)

# %%
TASK = 'MultiRC, metric=f1 mean value, method=cross validation'

matplotlib.rcParams.update({'font.size':15})



data_b = [data['bert-base']['cv']['8']['f1_mean'], 
             data['bert-base']['cv']['16']['f1_mean'], 
             data['bert-base']['cv']['32']['f1_mean'], 
             data['bert-base']['cv']['64']['f1_mean'], 
            ]

data_a = [data['albert-base']['cv']['8']['f1_mean'], 
             data['albert-base']['cv']['16']['f1_mean'], 
             data['albert-base']['cv']['32']['f1_mean'], 
             data['albert-base']['cv']['64']['f1_mean'], 
            ]

data_c = [data['albert-xxlarge']['cv']['8']['f1_mean'], 
             data['albert-xxlarge']['cv']['16']['f1_mean'], 
             data['albert-xxlarge']['cv']['32']['f1_mean'], 
             data['albert-xxlarge']['cv']['64']['f1_mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=0.2, ymax=0.7)
plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.2, ymax=0.7)

# %%
TASK = 'MultiRC, metric=f1 mean value, method=mdl'

matplotlib.rcParams.update({'font.size':15})



data_b = [data['bert-base']['mdl']['8']['f1_mean'], 
             data['bert-base']['mdl']['16']['f1_mean'], 
             data['bert-base']['mdl']['32']['f1_mean'], 
             data['bert-base']['mdl']['64']['f1_mean'], 
            ]

data_a = [data['albert-base']['mdl']['8']['f1_mean'], 
             data['albert-base']['mdl']['16']['f1_mean'], 
             data['albert-base']['mdl']['32']['f1_mean'], 
             data['albert-base']['mdl']['64']['f1_mean'], 
            ]

data_c = [data['albert-xxlarge']['mdl']['8']['f1_mean'], 
             data['albert-xxlarge']['mdl']['16']['f1_mean'], 
             data['albert-xxlarge']['mdl']['32']['f1_mean'], 
             data['albert-xxlarge']['mdl']['64']['f1_mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=0.2, ymax=0.7)
plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.2, ymax=0.7)

# %%
TASK = 'MultiRC, metric=EM mean value, method=multisplit'

matplotlib.rcParams.update({'font.size':15})



data_b = [data['bert-base']['dev32']['8']['em_mean'], 
             data['bert-base']['dev32']['16']['em_mean'], 
             data['bert-base']['dev32']['32']['em_mean'], 
             data['bert-base']['dev32']['64']['em_mean'], 
            ]

data_a = [data['albert-base']['dev32']['8']['em_mean'], 
             data['albert-base']['dev32']['16']['em_mean'], 
             data['albert-base']['dev32']['32']['em_mean'], 
             data['albert-base']['dev32']['64']['em_mean'], 
            ]

data_c = [data['albert-xxlarge']['dev32']['8']['em_mean'], 
             data['albert-xxlarge']['dev32']['16']['em_mean'], 
             data['albert-xxlarge']['dev32']['32']['em_mean'], 
             data['albert-xxlarge']['dev32']['64']['em_mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=0, ymax=0.2)
plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.0, ymax=0.2)

# %%
TASK = 'MultiRC, metric=EM mean value, method=cross validation'

matplotlib.rcParams.update({'font.size':15})



data_b = [data['bert-base']['cv']['8']['em_mean'], 
             data['bert-base']['cv']['16']['em_mean'], 
             data['bert-base']['cv']['32']['em_mean'], 
             data['bert-base']['cv']['64']['em_mean'], 
            ]

data_a = [data['albert-base']['cv']['8']['em_mean'], 
             data['albert-base']['cv']['16']['em_mean'], 
             data['albert-base']['cv']['32']['em_mean'], 
             data['albert-base']['cv']['64']['em_mean'], 
            ]

data_c = [data['albert-xxlarge']['cv']['8']['em_mean'], 
             data['albert-xxlarge']['cv']['16']['em_mean'], 
             data['albert-xxlarge']['cv']['32']['em_mean'], 
             data['albert-xxlarge']['cv']['64']['em_mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=0, ymax=0.2)
plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.0, ymax=0.2)

# %%
TASK = 'MultiRC, metric=EM mean value, method=mdl'

matplotlib.rcParams.update({'font.size':15})



data_b = [data['bert-base']['mdl']['8']['em_mean'], 
             data['bert-base']['mdl']['16']['em_mean'], 
             data['bert-base']['mdl']['32']['em_mean'], 
             data['bert-base']['mdl']['64']['em_mean'], 
            ]

data_a = [data['albert-base']['mdl']['8']['em_mean'], 
             data['albert-base']['mdl']['16']['em_mean'], 
             data['albert-base']['mdl']['32']['em_mean'], 
             data['albert-base']['mdl']['64']['em_mean'], 
            ]

data_c = [data['albert-xxlarge']['mdl']['8']['em_mean'], 
             data['albert-xxlarge']['mdl']['16']['em_mean'], 
             data['albert-xxlarge']['mdl']['32']['em_mean'], 
             data['albert-xxlarge']['mdl']['64']['em_mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=0, ymax=0.2)
plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.0, ymax=0.2)
