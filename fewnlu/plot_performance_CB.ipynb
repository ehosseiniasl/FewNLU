# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from matplotlib.transforms import Affine2D

import warnings
warnings.filterwarnings('ignore')

# %%
def plot_hyperparams(dev32, cv, mdl, title=''):
    fig, (ax0, ax1, ax2, ax3) = plt.subplots(ncols=4, sharey=True, figsize=(30,8))
    hp=0

    trans1 = Affine2D().translate(0.0, 0.0) + ax0.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax0.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax0.transData
    er1 = ax0.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax0.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax0.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
    ax0.set_title("HP1")
    ax0.set_xlabel('# shots')
    # ax0.legend(loc="upper right")
    # plt.show()
    ax0.grid()


    hp=1
    trans1 = Affine2D().translate(0.0, 0.0) + ax1.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax1.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax1.transData
    er1 = ax1.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax1.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax1.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
#     ax1.set_title(f"{TASK}, HP2")
    ax1.set_title("HP2")
    ax1.set_xlabel('# shots')
    # ax1.legend(loc="upper right")
    # plt.show()
    ax1.grid()

    hp=2
    trans1 = Affine2D().translate(0.0, 0.0) + ax2.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax2.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax2.transData
    er1 = ax2.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax2.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax2.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
    ax2.set_title("HP3")
    ax2.set_xlabel('# shots')
    # ax2.legend(loc="upper right")
    # plt.show()
    ax2.grid()

    hp=3
    trans1 = Affine2D().translate(0.0, 0.0) + ax3.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax3.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax3.transData
    er1 = ax3.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax3.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax3.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
    ax3.set_title("HP4")
    ax3.legend(loc="lower left")
    ax3.set_xlabel('# shots')

    # plt.show()ac
    ax3.grid()
    fig = plt.gcf()
    fig.suptitle(title, fontsize=30)
    return

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)
    return

def plot_bar(data_a, data_b, data_c, ymin=0.4, ymax=0.6):
    ticks = ['8', '16', '32', '64']
    
    plt.figure(figsize=(8,5))

    bpc = plt.boxplot(data_a, positions=np.array(range(len(data_a)))*2.0, widths=0.4)
    bpl = plt.boxplot(data_b, positions=np.array(range(len(data_b)))*2.0-0.45, widths=0.4)
    bpr = plt.boxplot(data_c, positions=np.array(range(len(data_c)))*2.0+0.45, widths=0.4)
    set_box_color(bpc, 'b')
    set_box_color(bpl, 'r')
    set_box_color(bpr, 'g')

    plt.plot([], c='b', label='multisplit')
    plt.plot([], c='r', label='cv')
    plt.plot([], c='g', label='mdl')

    plt.legend(loc='lower right')

    plt.xticks(range(0, len(ticks) * 2, 2), ticks)
    plt.xlim(-2, len(ticks)*2)
    plt.ylim(ymin, ymax)
    plt.tight_layout()
    plt.grid()
    plt.title(f"{TASK}")
    plt.xlabel('# shots')
    return

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)
    return

def plot_bar_models(data_a, label_a, data_b, label_b, data_c, label_c, ymin=0.4, ymax=0.6):
    ticks = ['8', '16', '32', '64']
    
    plt.figure(figsize=(8,5))

    bpl = plt.boxplot(data_a, positions=np.array(range(len(data_b)))*2.0-0.45, widths=0.4)
    bpc = plt.boxplot(data_b, positions=np.array(range(len(data_a)))*2.0, widths=0.4)
    bpr = plt.boxplot(data_c, positions=np.array(range(len(data_c)))*2.0+0.45, widths=0.4)
    set_box_color(bpl, 'b')
    set_box_color(bpc, 'r')
    set_box_color(bpr, 'g')

#     plt.plot([], c='b', label='bert-base')
#     plt.plot([], c='r', label='albert-base')
#     plt.plot([], c='g', label='albert-xxlarge')

    plt.plot([], c='b', label=label_a)
    plt.plot([], c='r', label=label_b)
    plt.plot([], c='g', label=label_c)

    plt.legend(loc='lower right')

    plt.xticks(range(0, len(ticks) * 2, 2), ticks)
    plt.xlim(-2, len(ticks)*2)
    plt.ylim(ymin, ymax)
    plt.tight_layout()
    plt.grid()
    plt.title(f"{TASK}")
    plt.xlabel('# shots')
    return

# %%
# CB
# Albert-xxlarge-v2

TITLE='task=CB, metric=accuracy, model=Albert-xxlarge-v2'

# plt.figure(figsize=(10,10))
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
        [0.5, 0.4375, 0.504, 0.625],
        [0.5625, 0.5267, 0.651, 0.678571],
        [0.5178, 0.5446, 0.593, 0.5491],
        [0.4866, 0.4732, 0.6339, 0.669642]
    ],
    'std': [
        [0.056,0.1633,0.076,0.0505],
        [0.0676,0.115,0.077,0.05646],
        [0.0743,0.023,0.073,0.07628],
        [0.1187,0.1283,0.017,0.01785]
           ]
}

cv = {
        'mean': [
            [0.6026, 0.46, 0.66, 0.678571],
            [0.558, 0.589, 0.63, 0.727678],
            [0.5223, 0.477, 0.625, 0.660714],
            [0.58, 0.598, 0.544, 0.709821]
        ],
    'std': [
        [0.0089,0.091,0.02,0.02916],
        [0.0748,0.085,0.066,0.04696],
        [0.059,0.068,0.052,0.05257],
        [0.1025,0.083,0.042,0.04464]
           ]
}

mdl = {
    'mean': [
        [0.562, 0.477, 0.562, 0.589285],
        [0.625, 0.482, 0.629, 0.678571],
        [0.549, 0.558, 0.607, 0.6026],
        [0.486, 0.553, 0.647, 0.72321]
    ],
    
    'std': [
        [0.088,0.081,0.08,0.065205],
        [0.02,0.156,0.06,0.10514],
        [0.055,0.044,0.025,0.094912],
        [0.094,0.121,0.051,0.02305]
    ]
}


plot_hyperparams(dev32, cv, mdl, TITLE)

# %%
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4
TASK = 'task=CB, metric=F1 score, model=Albert-xxlarge-v2'

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
        [0.3063, 0.34, 0.432, 0.49453],
        [0.38, 0.3695, 0.514, 0.553128],
        [0.34, 0.3994, 0.489, 0.431842],
        [0.316, 0.3298, 0.516, 0.567186]
    ],
    'std': [
        [0.0623,0.097,0.063,0.01197],
        [0.039,0.0926,0.109,0.08297],
        [0.085,0.024,0.079,0.046727],
        [0.1145,0.0912,0.083,0.013902]
           ]
}

cv = {
        'mean': [
            [0.4024, 0.347, 0.514, 0.578328],
            [0.359, 0.41, 0.501, 0.587979],
            [0.343, 0.36, 0.494, 0.500871],
            [0.3713, 0.409, 0.464, 0.565525]
        ],
    'std': [
        [0.019,0.056,0.074,0.06264],
        [0.0764,0.055,0.106,0.114517],
        [0.046,0.062,0.099,0.06676],
        [0.1061,0.068,0.059,0.11545]
           ]
}

mdl = {
    'mean': [
        [0.389, 0.327, 0.429, 0.474296],
        [0.418, 0.362, 0.524, 0.53881],
        [0.367, 0.38, 0.442, 0.508739],
        [0.315, 0.381, 0.489, 0.549991]
    ],
    
    'std': [
        [0.057,0.043,0.078,0.112842],
        [0.031,0.111,0.107,0.09572],
        [0.051,0.035,0.049,0.06784],
        [0.099,0.084,0.073,0.0926]
    ]
}

plot_hyperparams(dev32, cv, mdl, TASK)

# %%
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4
TASK = 'task=CB, metric=accuracy, model=Albert-base-v2'

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
        [0.52232, 0.495, 0.66, 0.66],
[0.553, 0.482, 0.656, 0.683],
[0.567, 0.504, 0.665, 0.687],
[0.566, 0.504, 0.678, 0.696]
    ],
    'std': [
        [0.1142,0.141,0.025,0.014],
[0.106,0.137,0.017,0.017],
[0.125,0.164,0.0304,0.0449],
[0.093,0.151,0.025,0.038]
           ]
}

cv = {
        'mean': [
            [0.638, 0.602, 0.669, 0.709],
[0.638, 0.589, 0.669, 0.718],
[0.674, 0.598, 0.665, 0.7],
[0.625, 0.584, 0.66, 0.745]
        ],
    'std': [
        [0.084,0.096,0.017,0.036],
[0.0816,0.097,0.03,0.039],
[0.039,0.069,0.017,0.0089],
[0.065,0.059,0.025,0.044]
           ]
}

mdl = {
    'mean': [
        [0.669, 0.593, 0.665, 0.669],
[0.642, 0.549, 0.683, 0.656],
[0.647, 0.598, 0.66, 0.651],
[0.625, 0.593, 0.656, 0.66]
    ],
    
    'std': [
        [0.044,0.129,0.017,0.017],
[0.063,0.136,0.017,0.044],
[0.026,0.105,0.025,0.023],
[0.046,0.165,0.022,0.038]
    ]
}

plot_hyperparams(dev32, cv, mdl, TASK)

# %%
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4
TASK = 'task=CB, metric=F1 score, model=Albert-base-v2'

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
        [0.317, 0.358, 0.487, 0.584],
[0.347, 0.351, 0.48, 0.584],
[0.355, 0.358, 0.515, 0.589],
[0.364, 0.356, 0.525, 0.597]
    ],
    'std': [
        [0.105,0.084,0.033,0.077],
[0.103,0.08,0.036,0.07],
[0.122,0.096,0.059,0.106],
[0.084,0.0931,0.074,0.093]
           ]
}

cv = {
        'mean': [
            [0.439, 0.413, 0.493, 0.609],
[0.436, 0.4, 0.544, 0.598],
[0.467, 0.41, 0.512, 0.547],
[0.428, 0.401, 0.507, 0.602]
        ],
    'std': [
        [0.064,0.074,0.056,0.064],
[0.073,0.082,0.051,0.097],
[0.024,0.047,0.061,0.065],
[0.049,0.04,0.052,0.11]
           ]
}

mdl = {
    'mean': [
        [0.567, 0.41, 0.515, 0.55],
[0.446, 0.383, 0.558, 0.557],
[0.451, 0.407, 0.511, 0.591],
[0.432, 0.406, 0.534, 0.585]
    ],
    
    'std': [
        [0.0319,0.095,0.048,0.063],
[0.0479,0.099,0.109,0.113],
[0.019,0.078,0.11,0.062],
[0.037,0.118,0.0426,0.127]
    ]
}

plot_hyperparams(dev32, cv, mdl, TASK)

# %%
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4
TASK = 'task=CB, metric=accuracy, model=bert-base-v2'

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
[0.602, 0.477, 0.683, 0.705],
[0.598, 0.477, 0.691, 0.714],
[0.531, 0.535, 0.678, 0.696],
[0.535, 0.526, 0.683, 0.7]
    ],
    'std': [
[0.079,0.136,0.0089,0.0103],
[0.06,0.164,0.017,0.014],
[0.104,0.131,0,0.038],
[0.103,0.16,0.0089,0.0089]
           ]
}

cv = {
        'mean': [
[0.616, 0.656, 0.656, 0.705],
[0.616, 0.647, 0.665, 0.723],
[0.575, 0.669, 0.678, 0.718],
[0.571, 0.665, 0.691, 0.727],
        ],
    'std': [
[0.047,0.062,0.026,0.023],
[0.047,0.039,0.017,0.037],
[0.039,0.045,0.025,0.017],
[0.038,0.0089,0.017,0.0089]
           ]
}

mdl = {
    'mean': [
[0.656, 0.593, 0.66, 0.723],
[0.66, 0.567, 0.66, 0.723],
[0.616, 0.571, 0.678, 0.714],
[0.611, 0.558, 0.683, 0.718]
    ],
    
    'std': [
        [0.046,0.065,0.038,0.023],
[0.035,0.102,0.038,0.023],
[0.034,0.043,0,0.014],
[0.044,0.064,0.0089,0.026]
    ]
}

plot_hyperparams(dev32, cv, mdl, TASK)

# %%
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4
TASK = 'task=CB, metric=F1 score, model=bert-base-v2'

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
[0.404, 0.316, 0.509, 0.565],
[0.398, 0.322, 0.526, 0.575],
[0.348, 0.35, 0.473, 0.542],
[0.351, 0.343, 0.477, 0.575]
    ],
    'std': [
[0.074,0.097,0.071,0.094],
[0.073,0.111,0.096,0.106],
[0.079,0.113,0,0.131],
[0.079,0.13,0.0061,0.096]
           ]
}

cv = {
        'mean': [
[0.408, 0.457, 0.486, 0.541],
[0.412, 0.451, 0.49, 0.595],
[0.379, 0.463, 0.476, 0.526],
[0.367, 0.457, 0.508, 0.558]
        ],
    'std': [
[0.047,0.043,0.062,0.071],
[0.045,0.027,0.05,0.09],
[0.014,0.028,0.013,0.059],
[0.036,0.0029,0.062,0.056]
           ]
}

mdl = {
    'mean': [
[0.457, 0.413, 0.461, 0.587],
[0.46, 0.395, 0.461, 0.592],
[0.427, 0.397, 0.496, 0.55],
[0.423, 0.388, 0.502, 0.571]
    ],
    
    'std': [
[0.033,0.048,0.027,0.119],
[0.026,0.071,0.027,0.115],
[0.027,0.03,0.045,0.067],
[0.034,0.043,0.057,0.095]
    ]
}

plot_hyperparams(dev32, cv, mdl, TASK)

# %%
# CB
# Albert-xxlarge-v2

TASK = 'CB, metric=accuracy mean value, model=Albert-xxlarge-v2'

matplotlib.rcParams.update({'font.size':15})


data = {
    'dev32': {
            '8': {
                'mean': [0.5, 0.5625, 0.5178, 0.4866],
                'std': [],
                'f1_mean': [0.3063, 0.38, 0.34, 0.316],
                'f1_std': []
            },
            '16': {
                'mean': [0.4375, 0.5267, 0.5446, 0.4732],
                'std': [],
                'f1_mean': [0.34, 0.3695, 0.3994, 0.3298],
                'f1_std': []
            },

            '32': {
                'mean': [0.504, 0.651, 0.593, 0.6339],
                'std': [],
                'f1_mean': [0.432, 0.514, 0.489, 0.516],
                'f1_std': []
            },
            '64': {
                'mean': [0.625, 0.678571, 0.5491, 0.669642],
                'std': [],
                'f1_mean': [0.49453, 0.553128, 0.431842, 0.567186],
                'f1_std': []
            }
    },
    
    'cv': {
            '8': {
                'mean': [0.6026, 0.558, 0.5223, 0.58],
                'std': [],
                'f1_mean': [0.4024, 0.359, 0.343, 0.3713],
                'f1_std': []
            },
            '16': {
                'mean': [0.46, 0.589, 0.477, 0.598],
                'std': [],
                'f1_mean': [0.347, 0.41, 0.36, 0.409],
                'f1_std': []
            },

            '32': {
                'mean': [0.66, 0.63, 0.625, 0.544],
                'std': [],
                'f1_mean': [0.514, 0.501, 0.494 ,0.464],
                'f1_std': []
            },
            '64': {
                'mean': [0.678571, 0.727678, 0.660714, 0.709821],
                'std': [],
                'f1_mean': [0.578328, 0.587979, 0.500871, 0.565525],
                'f1_std': []
            }
    },
    
    'mdl': {
            '8': {
                'mean': [0.562, 0.625, 0.549, 0.486],
                'std': [],
                'f1_mean': [0.389, 0.418, 0.367, 0.315],
                'f1_std': []
            },
            '16': {
                'mean': [0.477, 0.482, 0.558, 0.553],
                'std': [],
                'f1_mean': [0.327, 0.362, 0.38, 0.381],
                'f1_std': []
            },

            '32': {
                'mean': [0.562, 0.629, 0.607, 0.647],
                'std': [],
                'f1_mean': [0.429, 0.524, 0.442, 0.489],
                'f1_std': []
            },
            '64': {
                'mean': [0.589285, 0.678571, 0.6026, 0.72321],
                'std': [],
                'f1_mean': [0.474296, 0.53881, 0.508739, 0.549991],
                'f1_std': []
            }
    }
    

}

data_a = [data['dev32']['8']['mean'], 
             data['dev32']['16']['mean'], 
             data['dev32']['32']['mean'], 
             data['dev32']['64']['mean'], 
            ]

data_b = [data['cv']['8']['mean'], 
             data['cv']['16']['mean'], 
             data['cv']['32']['mean'], 
             data['cv']['64']['mean'], 
            ]

data_c = [data['mdl']['8']['mean'], 
             data['mdl']['16']['mean'], 
             data['mdl']['32']['mean'], 
             data['mdl']['64']['mean'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0.4, ymax=0.8)

# %%
#CB F1 
# Albert-xxlarge-v2

TASK = 'CB, metric=f1 mean value, model=Albert-xxlarge-v2'

data_a = [data['dev32']['8']['f1_mean'], 
             data['dev32']['16']['f1_mean'], 
             data['dev32']['32']['f1_mean'], 
             data['dev32']['64']['f1_mean'], 
            ]

data_b = [data['cv']['8']['f1_mean'], 
             data['cv']['16']['f1_mean'], 
             data['cv']['32']['f1_mean'], 
             data['cv']['64']['f1_mean'], 
            ]

data_c = [data['mdl']['8']['f1_mean'], 
             data['mdl']['16']['f1_mean'], 
             data['mdl']['32']['f1_mean'], 
             data['mdl']['64']['f1_mean'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0.2, ymax=0.65)

# %%
# CB
# Albert-base-v2

TASK = 'CB, metric=accuracy mean value, model=Albert-base-v2'

matplotlib.rcParams.update({'font.size':15})


data = {
    'albert-base': {
        'dev32': {
            '8': {
                'mean': [0.1142, 0.106, 0.125, 0.093],
                'f1_mean': [0.317,0.347,0.355,0.364],
            },
            '16': {
                'mean': [0.495, 0.482, 0.504, 0.504],
                'f1_mean': [0.358,0.351,0.358,0.356],
            },

            '32': {
                'mean': [0.66, 0.656, 0.665, 0.678],
                'f1_mean': [0.487,0.48,0.515,0.525],
            },
            '64': {
                'mean': [0.66, 0.683, 0.687, 0.696],
                'f1_mean': [0.584,0.584,0.589,0.597],
            }
        },
        'cv': {
            '8': {
                'mean': [0.638,0.638,0.674,0.625],
                'f1_mean': [0.439,0.436,0.467,0.428],
            },
            '16': {
                'mean': [0.602,0.589,0.598,0.584],
                'f1_mean': [0.413,0.4,0.41,0.401],
            },

            '32': {
                'mean': [0.669,0.669,0.665,0.66],
                'f1_mean': [0.493,0.544,0.512,0.507],
            },
            '64': {
                'mean': [0.036,0.039,0.0089,0.044],
                'f1_mean': [0.609,0.598,0.547,0.602],
            }
        },
    
        'mdl': {
            '8': {
                'mean': [0.669,0.642,0.647,0.625],
                'f1_mean': [0.567,0.446,0.451,0.432],
            },
            '16': {
                'mean': [0.593,0.549,0.598,0.593],
                'f1_mean': [0.41,0.383,0.407,0.406],
            },

            '32': {
                'mean': [0.665, 0.683, 0.66, 0.656],
                'f1_mean': [0.515,0.558,0.511,0.534],
            },
            '64': {
                'mean': [0.669,0.656,0.651,0.66],
                'f1_mean': [0.55,0.557,0.591,0.585],
            }
        }
    },
    
    'bert-base':
    {
        'dev32': {
            '8': {
                'mean': [0.602, 0.598, 0.531, 0.535],
                'f1_mean': [0.404, 0.398, 0.348, 0.351],
            },
            '16': {
                'mean': [0.477,0.477,0.535,0.526],
                'f1_mean': [0.316, 0.322, 0.35, 0.343],
            },

            '32': {
                'mean': [0.683, 0.691, 0.678, 0.683],
                'f1_mean': [0.509,0.526,0.473,0.477],
            },
            '64': {
                'mean': [0.705, 0.714, 0.696, 0.7],
                'f1_mean': [0.565,0.575,0.542,0.575],
            }
        },
        'cv': {
            '8': {
                'mean': [0.616,0.616,0.575,0.571],
                'f1_mean': [0.408,0.412,0.379,0.367],
            },
            '16': {
                'mean': [0.656,0.647,0.669,0.665],
                'f1_mean': [0.457,0.451,0.463,0.457],
            },

            '32': {
                'mean': [0.656,0.665,0.678,0.691],
                'f1_mean': [0.486,0.49,0.476,0.508],
            },
            '64': {
                'mean': [0.705,0.723,0.718,0.727],
                'f1_mean': [0.541,0.595,0.526,0.558],
            }
        },
    
        'mdl': {
            '8': {
                'mean': [0.656,0.66,0.616,0.611],
                'f1_mean': [0.457,0.46,0.427,0.423],
            },
            '16': {
                'mean': [0.593,0.567,0.571,0.558],
                'f1_mean': [0.413,0.395,0.397,0.388],
            },

            '32': {
                'mean': [0.66,0.66,0.678,0.683],
                'f1_mean': [0.461,0.461,0.496,0.502],
            },
            '64': {
                'mean': [0.723,0.723,0.714,0.718],
                'f1_mean': [0.587,0.592,0.55,0.571],
            }
        }
    },
    
    'albert-xxlarge': {
        'dev32': {
            '8': {
                'mean': [0.5, 0.5625, 0.5178, 0.4866],
                'f1_mean': [0.3063, 0.38, 0.34, 0.316],
            },
            '16': {
                'mean': [0.4375, 0.5267, 0.5446, 0.4732],
                'f1_mean': [0.34, 0.3695, 0.3994, 0.3298],
            },

            '32': {
                'mean': [0.504, 0.651, 0.593, 0.6339],
                'f1_mean': [0.432, 0.514, 0.489, 0.516],
            },
            '64': {
                'mean': [0.625, 0.678571, 0.5491, 0.669642],
                'f1_mean': [0.49453, 0.553128, 0.431842, 0.567186],
            }
    },
    
    'cv': {
            '8': {
                'mean': [0.6026, 0.558, 0.5223, 0.58],
                'f1_mean': [0.4024, 0.359, 0.343, 0.3713],
            },
            '16': {
                'mean': [0.46, 0.589, 0.477, 0.598],
                'f1_mean': [0.347, 0.41, 0.36, 0.409],
            },

            '32': {
                'mean': [0.66, 0.63, 0.625, 0.544],
                'f1_mean': [0.514, 0.501, 0.494 ,0.464],
            },
            '64': {
                'mean': [0.678571, 0.727678, 0.660714, 0.709821],
                'f1_mean': [0.578328, 0.587979, 0.500871, 0.565525],
            }
    },
    
    'mdl': {
            '8': {
                'mean': [0.562, 0.625, 0.549, 0.486],
                'f1_mean': [0.389, 0.418, 0.367, 0.315],
            },
            '16': {
                'mean': [0.477, 0.482, 0.558, 0.553],
                'f1_mean': [0.327, 0.362, 0.38, 0.381],
            },

            '32': {
                'mean': [0.562, 0.629, 0.607, 0.647],
                'f1_mean': [0.429, 0.524, 0.442, 0.489],
            },
            '64': {
                'mean': [0.589285, 0.678571, 0.6026, 0.72321],
                'f1_mean': [0.474296, 0.53881, 0.508739, 0.549991],
            }
    }
    }

}

data_a = [data['albert-base']['dev32']['8']['mean'], 
             data['albert-base']['dev32']['16']['mean'], 
             data['albert-base']['dev32']['32']['mean'], 
             data['albert-base']['dev32']['64']['mean'], 
            ]

data_b = [data['albert-base']['cv']['8']['mean'], 
             data['albert-base']['cv']['16']['mean'], 
             data['albert-base']['cv']['32']['mean'], 
             data['albert-base']['cv']['64']['mean'], 
            ]

data_c = [data['albert-base']['mdl']['8']['mean'], 
             data['albert-base']['mdl']['16']['mean'], 
             data['albert-base']['mdl']['32']['mean'], 
             data['albert-base']['mdl']['64']['mean'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0.4, ymax=0.8)

# %%
TASK = 'CB, metric=f1 mean value, model=Albert-base-v2'

matplotlib.rcParams.update({'font.size':15})


data_a = [data['albert-base']['dev32']['8']['f1_mean'], 
             data['albert-base']['dev32']['16']['f1_mean'], 
             data['albert-base']['dev32']['32']['f1_mean'], 
             data['albert-base']['dev32']['64']['f1_mean'], 
            ]

data_b = [data['albert-base']['cv']['8']['f1_mean'], 
             data['albert-base']['cv']['16']['f1_mean'], 
             data['albert-base']['cv']['32']['f1_mean'], 
             data['albert-base']['cv']['64']['f1_mean'], 
            ]

data_c = [data['albert-base']['mdl']['8']['f1_mean'], 
             data['albert-base']['mdl']['16']['f1_mean'], 
             data['albert-base']['mdl']['32']['f1_mean'], 
             data['albert-base']['mdl']['64']['f1_mean'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0.2, ymax=0.65)

# %%
TASK = 'CB, metric=accuracy mean value, model=bert-base-v2'

data_a = [data['bert-base']['dev32']['8']['mean'], 
             data['bert-base']['dev32']['16']['mean'], 
             data['bert-base']['dev32']['32']['mean'], 
             data['bert-base']['dev32']['64']['mean'], 
            ]

data_b = [data['bert-base']['cv']['8']['mean'], 
             data['bert-base']['cv']['16']['mean'], 
             data['bert-base']['cv']['32']['mean'], 
             data['bert-base']['cv']['64']['mean'], 
            ]

data_c = [data['bert-base']['mdl']['8']['mean'], 
             data['bert-base']['mdl']['16']['mean'], 
             data['bert-base']['mdl']['32']['mean'], 
             data['bert-base']['mdl']['64']['mean'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0.4, ymax=0.8)

# %%
TASK = 'CB, metric=f1 mean value, model=bert-base-v2'

data_a = [data['bert-base']['dev32']['8']['f1_mean'], 
             data['bert-base']['dev32']['16']['f1_mean'], 
             data['bert-base']['dev32']['32']['f1_mean'], 
             data['bert-base']['dev32']['64']['f1_mean'], 
            ]

data_b = [data['bert-base']['cv']['8']['f1_mean'], 
             data['bert-base']['cv']['16']['f1_mean'], 
             data['bert-base']['cv']['32']['f1_mean'], 
             data['bert-base']['cv']['64']['f1_mean'], 
            ]

data_c = [data['bert-base']['mdl']['8']['f1_mean'], 
             data['bert-base']['mdl']['16']['f1_mean'], 
             data['bert-base']['mdl']['32']['f1_mean'], 
             data['bert-base']['mdl']['64']['f1_mean'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0.2, ymax=0.65)

# %%
TASK = 'CB, metric=accuracy mean value, method=multisplit'

matplotlib.rcParams.update({'font.size':15})



data_b = [data['bert-base']['dev32']['8']['mean'], 
             data['bert-base']['dev32']['16']['mean'], 
             data['bert-base']['dev32']['32']['mean'], 
             data['bert-base']['dev32']['64']['mean'], 
            ]

data_a = [data['albert-base']['dev32']['8']['mean'], 
             data['albert-base']['dev32']['16']['mean'], 
             data['albert-base']['dev32']['32']['mean'], 
             data['albert-base']['dev32']['64']['mean'], 
            ]

data_c = [data['albert-xxlarge']['dev32']['8']['mean'], 
             data['albert-xxlarge']['dev32']['16']['mean'], 
             data['albert-xxlarge']['dev32']['32']['mean'], 
             data['albert-xxlarge']['dev32']['64']['mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=0.0, ymax=0.8)

plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.0, ymax=0.8)

# %%
TASK = 'CB, metric=accuracy mean value, method=cross validation'

matplotlib.rcParams.update({'font.size':15})



data_b = [data['bert-base']['cv']['8']['mean'], 
             data['bert-base']['cv']['16']['mean'], 
             data['bert-base']['cv']['32']['mean'], 
             data['bert-base']['cv']['64']['mean'], 
            ]

data_a = [data['albert-base']['cv']['8']['mean'], 
             data['albert-base']['cv']['16']['mean'], 
             data['albert-base']['cv']['32']['mean'], 
             data['albert-base']['cv']['64']['mean'], 
            ]

data_c = [data['albert-xxlarge']['cv']['8']['mean'], 
             data['albert-xxlarge']['cv']['16']['mean'], 
             data['albert-xxlarge']['cv']['32']['mean'], 
             data['albert-xxlarge']['cv']['64']['mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=0.0, ymax=0.8)

plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.0, ymax=0.8)

# %%
TASK = 'CB, metric=accuracy mean value, method=mdl'

matplotlib.rcParams.update({'font.size':15})



data_b = [data['bert-base']['mdl']['8']['mean'], 
             data['bert-base']['mdl']['16']['mean'], 
             data['bert-base']['mdl']['32']['mean'], 
             data['bert-base']['mdl']['64']['mean'], 
            ]

data_a = [data['albert-base']['mdl']['8']['mean'], 
             data['albert-base']['mdl']['16']['mean'], 
             data['albert-base']['mdl']['32']['mean'], 
             data['albert-base']['mdl']['64']['mean'], 
            ]

data_c = [data['albert-xxlarge']['mdl']['8']['mean'], 
             data['albert-xxlarge']['mdl']['16']['mean'], 
             data['albert-xxlarge']['mdl']['32']['mean'], 
             data['albert-xxlarge']['mdl']['64']['mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=0.0, ymax=0.8)

plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.0, ymax=0.8)
