# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from matplotlib.transforms import Affine2D

import warnings
warnings.filterwarnings('ignore')

# %%
def plot_hyperparams(dev32, cv, mdl, title=''):
    fig, (ax0, ax1, ax2, ax3) = plt.subplots(ncols=4, sharey=True, figsize=(30,8))
    hp=0

    trans1 = Affine2D().translate(0.0, 0.0) + ax0.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax0.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax0.transData
    er1 = ax0.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax0.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax0.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
    ax0.set_title("HP1")
    ax0.set_xlabel('# shots')
    # ax0.legend(loc="upper right")
    # plt.show()
    ax0.grid()


    hp=1
    trans1 = Affine2D().translate(0.0, 0.0) + ax1.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax1.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax1.transData
    er1 = ax1.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax1.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax1.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
#     ax1.set_title(f"{TASK}, HP2")
    ax1.set_title("HP2")
    ax1.set_xlabel('# shots')
    # ax1.legend(loc="upper right")
    # plt.show()
    ax1.grid()

    hp=2
    trans1 = Affine2D().translate(0.0, 0.0) + ax2.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax2.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax2.transData
    er1 = ax2.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax2.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax2.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
    ax2.set_title("HP3")
    ax2.set_xlabel('# shots')
    # ax2.legend(loc="upper right")
    # plt.show()
    ax2.grid()

    hp=3
    trans1 = Affine2D().translate(0.0, 0.0) + ax3.transData
    trans2 = Affine2D().translate(-0.1, 0.0) + ax3.transData
    trans3 = Affine2D().translate(+0.1, 0.0) + ax3.transData
    er1 = ax3.errorbar(x, dev32['mean'][hp], yerr=dev32['std'][hp], label='multisplit', marker='o', fmt='o', color='blue', linewidth=LINEWIDTH, linestyle='none', transform=trans1)
    er2 = ax3.errorbar(x, cv['mean'][hp], yerr=cv['std'][hp], label='cv', marker='o', fmt='o', color='red', linewidth=LINEWIDTH, linestyle='none', transform=trans2)
    er3 = ax3.errorbar(x, mdl['mean'][hp], yerr=mdl['std'][hp], label='mdl', marker='o', fmt='o', color='green', linewidth=LINEWIDTH, linestyle='none', transform=trans3)
    ax3.set_title("HP4")
    ax3.legend(loc="lower left")
    ax3.set_xlabel('# shots')

    # plt.show()ac
    ax3.grid()
    fig = plt.gcf()
    fig.suptitle(title, fontsize=30)
    return

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)
    return

def plot_bar(data_a, data_b, data_c, ymin=0.4, ymax=0.6):
    ticks = ['8', '16', '32', '64']
    
    plt.figure(figsize=(8,5))

    bpc = plt.boxplot(data_a, positions=np.array(range(len(data_a)))*2.0, widths=0.4)
    bpl = plt.boxplot(data_b, positions=np.array(range(len(data_b)))*2.0-0.45, widths=0.4)
    bpr = plt.boxplot(data_c, positions=np.array(range(len(data_c)))*2.0+0.45, widths=0.4)
    set_box_color(bpc, 'b')
    set_box_color(bpl, 'r')
    set_box_color(bpr, 'g')

    plt.plot([], c='b', label='multisplit')
    plt.plot([], c='r', label='cv')
    plt.plot([], c='g', label='mdl')

    plt.legend(loc='lower right')

    plt.xticks(range(0, len(ticks) * 2, 2), ticks)
    plt.xlim(-2, len(ticks)*2)
    plt.ylim(ymin, ymax)
    plt.tight_layout()
    plt.grid()
    plt.title(f"{TASK}")
    plt.xlabel('# shots')
    return

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)
    return

def plot_bar_models(data_a, label_a, data_b, label_b, data_c, label_c, ymin=0.4, ymax=0.6):
    ticks = ['8', '16', '32', '64']
    
    plt.figure(figsize=(8,5))

    bpl = plt.boxplot(data_a, positions=np.array(range(len(data_b)))*2.0-0.45, widths=0.4)
    bpc = plt.boxplot(data_b, positions=np.array(range(len(data_a)))*2.0, widths=0.4)
    bpr = plt.boxplot(data_c, positions=np.array(range(len(data_c)))*2.0+0.45, widths=0.4)
    set_box_color(bpl, 'b')
    set_box_color(bpc, 'r')
    set_box_color(bpr, 'g')

#     plt.plot([], c='b', label='bert-base')
#     plt.plot([], c='r', label='albert-base')
#     plt.plot([], c='g', label='albert-xxlarge')

    plt.plot([], c='b', label=label_a)
    plt.plot([], c='r', label=label_b)
    plt.plot([], c='g', label=label_c)

    plt.legend(loc='lower right')

    plt.xticks(range(0, len(ticks) * 2, 2), ticks)
    plt.xlim(-2, len(ticks)*2)
    plt.ylim(ymin, ymax)
    plt.tight_layout()
    plt.grid()
    plt.title(f"{TASK}")
    plt.xlabel('# shots')
    return

# %%
# MultiRC
# Albert-xxlarge-v2

TITLE='task=WSC, metric=accuracy, model=Albert-xxlarge-v2'

# plt.figure(figsize=(10,10))
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
        [0.5384, 0.5432, 0.512, 0.512],
        [0.5769, 0.4567, 0.5288, 0.5697],
        [0.5312, 0.4903, 0.5384, 0.5889],
        [0.5456, 0.4759, 0.5528, 0.4783]
    ],
    'std': [
        [0.109,0.0364,0.0733,0.0817],
        [0.1218,0.1066,0.0732,0.0418],
        [0.1181,0.0457,0.0925,0.0336],
        [0.1165,0.0975,0.0328,0.0568]
           ]
}

cv = {
        'mean': [
            [0.56, 0.5625, 0.5721, 0.5336],
            [0.536, 0.4615, 0.4807, 0.4687],
            [0.5024, 0.4543, 0.4687, 0.5552],
            [0.5312, 0.4639, 0.5288, 0.5456]
        ],
    'std': [
        [0.062,0.0396,0.044,0.08025],
        [0.0432,0.0538,0.087,0.08322],
        [0.1141,0.086,0.024,0.0708],
        [0.1027,0.069,0.0323,0.0813]
           ]
}

mdl = {
    'mean': [
        [0.56, 0.55, 0.526, 0.4783],
        [0.557, 0.48, 0.521, 0.4951],
        [0.495, 0.509, 0.531, 0.5312],
        [0.524, 0.509, 0.548, 0.5072]
    ],
    
    'std': [
        [0.074,0.069,0.091,0.0317],
        [0.095,0.107,0.056,0.0372],
        [0.089,0.097,0.099,0.0517],
        [0.098,0.099,0.096,0.0872]
    ]
}


plot_hyperparams(dev32, cv, mdl, TITLE)

# %%
# WSC
# bert-base-v2

TITLE='task=WSC, metric=accuracy, model=Albert-base-v2'

# plt.figure(figsize=(10,10))
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
[0.519, 0.531, 0.524, 0.541],
[0.528, 0.531, 0.516, 0.537],
[0.512, 0.495, 0.495, 0.545],
[0.521, 0.502, 0.519, 0.557]
    ],
    'std': [
[0.0905,0.064,0.0779,0.04],
[0.095,0.0708,0.076,0.047],
[0.107,0.084,0.067,0.048],
[0.096,0.073,0.084,0.033]
           ]
}

cv = {
        'mean': [
[0.507, 0.512, 0.49, 0.537],
[0.49, 0.524, 0.478, 0.555],
[0.483, 0.497, 0.495, 0.531],
[0.46, 0.507, 0.514, 0.533]
        ],
    'std': [
[0.073,0.089,0.052,0.029],
[0.079,0.102,0.086,0.0204],
[0.061,0.088,0.086,0.024],
[0.025,0.084,0.043,0.025]
           ]
}

mdl = {
    'mean': [
[0.564, 0.528, 0.507, 0.497],
[0.55, 0.528, 0.461, 0.483],
[0.528, 0.526, 0.516, 0.507],
[0.55, 0.528, 0.524, 0.528]
    ],
    
    'std': [
[0.072,0.101,0.059,0.057],
[0.068,0.087,0.059,0.031],
[0.087,0.051,0.059,0.041],
[0.073,0.035,0.049,0.023]
    ]
}


plot_hyperparams(dev32, cv, mdl, TITLE)

# %%
# WSC
# Albert-base-v2

TITLE='task=WSC, metric=accuracy, model=bert-base-v2'

# plt.figure(figsize=(10,10))
matplotlib.rcParams.update({'font.size':20})
LINEWIDTH=4

x = ['8', '16', '32', '64']

dev32 = {
    'mean': [
[0.531, 0.512, 0.502, 0.514],
[0.512, 0.526, 0.492, 0.516],
[0.56, 0.526, 0.5, 0.514],
[0.536, 0.536, 0.48, 0.487]
    ],
    'std': [
[0.071,0.09,0.085,0.048],
[0.082,0.088,0.11,0.052],
[0.074,0.095,0.075,0.07],
[0.086,0.095,0.082,0.047]
           ]
}

cv = {
        'mean': [
[0.531, 0.512, 0.502, 0.514],
[0.512, 0.526, 0.492, 0.516],
[0.56, 0.526, 0.5, 0.514],
[0.536, 0.536, 0.48, 0.487]
        ],
    'std': [
[0.071,0.09,0.085,0.048],
[0.082,0.088,0.112,0.051],
[0.074,0.095,0.075,0.0708],
[0.086,0.095,0.082,0.047]
           ]
}

mdl = {
    'mean': [
[0.545, 0.538, 0.502, 0.528],
[0.548, 0.536, 0.483, 0.461],
[0.545, 0.524, 0.502, 0.507],
[0.557, 0.502, 0.492, 0.526]
    ],
    
    'std': [
[0.108,0.095,0.071,0.024],
[0.118,0.11,0.089,0.059],
[0.072,0.106,0.088,0.044],
[0.063,0.119,0.093,0.041]
    ]
}


plot_hyperparams(dev32, cv, mdl, TITLE)

# %%
# MultiRC
# Albert-xxlarge-v2

TASK = 'WSC, metric=accuracy mean value, model=Albert-xxlarge-v2'

matplotlib.rcParams.update({'font.size':15})

data = {
    'dev32': {
            '8': {
                'mean': [0.5384, 0.5769, 0.5312, 0.5456],
                'std': [0.109, 0.1218, 0.1181, 0.1165]
            },
            '16': {
                'mean': [0.5432, 0.4567, 0.4903, 0.4759],
                'std': [0.0364, 0.1066, 0.0457, 0.0975]
            },

            '32': {
                'mean': [0.512, 0.5288, 0.5384, 0.5528],
                'std': [0.0733, 0.0732, 0.0925, 0.0328]
            },
            '64': {
                'mean': [0.512, 0.5697, 0.5889, 0.4783],
                'std': [0.0817, 0.0418, 0.0336, 0.0568]
            }
    },
    
    'cv': {
            '8': {
                'mean': [0.56, 0.536, 0.5024, 0.5312],
                'std': [0.062, 0.0432, 0.1141, 0.1027]
            },
            '16': {
                'mean': [0.5625, 0.4615, 0.4543, 0.4639],
                'std': [0.0396, 0.0538, 0.086, 0.069]
            },

            '32': {
                'mean': [0.5721, 0.4807, 0.4687, 0.5288],
                'std': [0.044, 0.087, 0.024, 0.0323]
            },
            '64': {
                'mean': [0.5336, 0.4687, 0.5552, 0.5456],
                'std': [0.08025, 0.08322, 0.0708, 0.0813]
            }
    },
    
    'mdl': {
            '8': {
                'mean': [0.56, 0.557, 0.495, 0.524],
                'std': [0.074, 0.095, 0.089, 0.098]
            },
            '16': {
                'mean': [0.55, 0.48, 0.509, 0.509],
                'std': [0.069, 0.107, 0.097, 0.099]
            },

            '32': {
                'mean': [0.526, 0.521, 0.531, 0.548],
                'std': [0.091, 0.056, 0.099, 0.096]
            },
            '64': {
                'mean': [0.4783, 0.4951, 0.5312, 0.5072],
                'std': [0.0317, 0.0372, 0.0517, 0.0872]
            }
    }
    

}
    

data_a = [data['dev32']['8']['mean'], 
             data['dev32']['16']['mean'], 
             data['dev32']['32']['mean'], 
             data['dev32']['64']['mean'], 
            ]

data_b = [data['cv']['8']['mean'], 
             data['cv']['16']['mean'], 
             data['cv']['32']['mean'], 
             data['cv']['64']['mean'], 
            ]

data_c = [data['mdl']['8']['mean'], 
             data['mdl']['16']['mean'], 
             data['mdl']['32']['mean'], 
             data['mdl']['64']['mean'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0.4, ymax=0.64)

# %%
# MultiRC
# Albert-base-v2

TASK = 'WSC, metric=accuracy mean value, model=Albert-base-v2'

matplotlib.rcParams.update({'font.size':15})

data = {
    'albert-xxlarge':
    {
        'dev32': {
            '8': {
                'mean': [0.5384, 0.5769, 0.5312, 0.5456],
                'std': [0.109, 0.1218, 0.1181, 0.1165]
            },
            '16': {
                'mean': [0.5432, 0.4567, 0.4903, 0.4759],
                'std': [0.0364, 0.1066, 0.0457, 0.0975]
            },

            '32': {
                'mean': [0.512, 0.5288, 0.5384, 0.5528],
                'std': [0.0733, 0.0732, 0.0925, 0.0328]
            },
            '64': {
                'mean': [0.512, 0.5697, 0.5889, 0.4783],
                'std': [0.0817, 0.0418, 0.0336, 0.0568]
            }
    },
    
    'cv': {
            '8': {
                'mean': [0.56, 0.536, 0.5024, 0.5312],
                'std': [0.062, 0.0432, 0.1141, 0.1027]
            },
            '16': {
                'mean': [0.5625, 0.4615, 0.4543, 0.4639],
                'std': [0.0396, 0.0538, 0.086, 0.069]
            },

            '32': {
                'mean': [0.5721, 0.4807, 0.4687, 0.5288],
                'std': [0.044, 0.087, 0.024, 0.0323]
            },
            '64': {
                'mean': [0.5336, 0.4687, 0.5552, 0.5456],
                'std': [0.08025, 0.08322, 0.0708, 0.0813]
            }
    },
    
    'mdl': {
            '8': {
                'mean': [0.56, 0.557, 0.495, 0.524],
                'std': [0.074, 0.095, 0.089, 0.098]
            },
            '16': {
                'mean': [0.55, 0.48, 0.509, 0.509],
                'std': [0.069, 0.107, 0.097, 0.099]
            },

            '32': {
                'mean': [0.526, 0.521, 0.531, 0.548],
                'std': [0.091, 0.056, 0.099, 0.096]
            },
            '64': {
                'mean': [0.4783, 0.4951, 0.5312, 0.5072],
                'std': [0.0317, 0.0372, 0.0517, 0.0872]
            }
    }
    
    },
    'albert-base': {
        'dev32': {
                '8': {
                    'mean': [0.519, 0.528, 0.512, 0.521],
                },
                '16': {
                    'mean': [0.531, 0.531, 0.495, 0.502],
                },

                '32': {
                    'mean': [0.524,0.516,0.495,0.519]
                },
                '64': {
                    'mean': [0.541,0.537,0.545,0.557],
                }
        },

        'cv': {
                '8': {
                    'mean': [0.507,0.49,0.483,0.46],
                },
                '16': {
                    'mean': [0.512,0.524,0.497,0.507],
                },

                '32': {
                    'mean': [0.49,0.478,0.495,0.514],
                },
                '64': {
                    'mean': [0.537,0.555,0.531,0.533],
                }
        },

        'mdl': {
                '8': {
                    'mean': [0.564,0.55,0.528,0.55],
                },
                '16': {
                    'mean': [0.528,0.528,0.526,0.528],
                },

                '32': {
                    'mean': [0.507,0.461,0.516,0.524],
                },
                '64': {
                    'mean': [0.497,0.483,0.507,0.528],
                }
        }
    },
    'bert-base':
    {
        'dev32': {
                '8': {
                    'mean': [0.531, 0.512, 0.56, 0.536],
                },
                '16': {
                    'mean': [0.512, 0.526, 0.526, 0.536],
                },

                '32': {
                    'mean': [0.502, 0.492, 0.5, 0.48]
                },
                '64': {
                    'mean': [0.514, 0.516, 0.514, 0.487],
                }
        },

        'cv': {
                '8': {
                    'mean': [0.531,0.512,0.56,0.536],
                },
                '16': {
                    'mean': [0.512,0.526,0.526,0.536],
                },

                '32': {
                    'mean': [0.502,0.492,0.5,0.48],
                },
                '64': {
                    'mean': [0.514,0.516,0.514,0.487],
                }
        },

        'mdl': {
                '8': {
                    'mean': [0.545,0.548,0.545,0.557],
                },
                '16': {
                    'mean': [0.538,0.536,0.524,0.502],
                },

                '32': {
                    'mean': [0.502,0.483,0.502,0.492],
                },
                '64': {
                    'mean': [0.528,0.461,0.507,0.526],
                }
        }
        
    }

}
    

data_a = [data['albert-base']['dev32']['8']['mean'], 
             data['albert-base']['dev32']['16']['mean'], 
             data['albert-base']['dev32']['32']['mean'], 
             data['albert-base']['dev32']['64']['mean'], 
            ]

data_b = [data['albert-base']['cv']['8']['mean'], 
             data['albert-base']['cv']['16']['mean'], 
             data['albert-base']['cv']['32']['mean'], 
             data['albert-base']['cv']['64']['mean'], 
            ]

data_c = [data['albert-base']['mdl']['8']['mean'], 
             data['albert-base']['mdl']['16']['mean'], 
             data['albert-base']['mdl']['32']['mean'], 
             data['albert-base']['mdl']['64']['mean'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0.4, ymax=0.64)

# %%
TASK = 'WSC, metric=accuracy mean value, model=bert-base-v2'

matplotlib.rcParams.update({'font.size':15})


data_a = [data['bert-base']['dev32']['8']['mean'], 
             data['bert-base']['dev32']['16']['mean'], 
             data['bert-base']['dev32']['32']['mean'], 
             data['bert-base']['dev32']['64']['mean'], 
            ]

data_b = [data['bert-base']['cv']['8']['mean'], 
             data['bert-base']['cv']['16']['mean'], 
             data['bert-base']['cv']['32']['mean'], 
             data['bert-base']['cv']['64']['mean'], 
            ]

data_c = [data['bert-base']['mdl']['8']['mean'], 
             data['bert-base']['mdl']['16']['mean'], 
             data['bert-base']['mdl']['32']['mean'], 
             data['bert-base']['mdl']['64']['mean'], 
            ]


plot_bar(data_a, data_b, data_c, ymin=0.4, ymax=0.64)

# %%
TASK = 'WSC, metric=accuracy mean value, method=multisplit'

matplotlib.rcParams.update({'font.size':15})



data_b = [data['bert-base']['dev32']['8']['mean'], 
             data['bert-base']['dev32']['16']['mean'], 
             data['bert-base']['dev32']['32']['mean'], 
             data['bert-base']['dev32']['64']['mean'], 
            ]

data_a = [data['albert-base']['dev32']['8']['mean'], 
             data['albert-base']['dev32']['16']['mean'], 
             data['albert-base']['dev32']['32']['mean'], 
             data['albert-base']['dev32']['64']['mean'], 
            ]

data_c = [data['albert-xxlarge']['dev32']['8']['mean'], 
             data['albert-xxlarge']['dev32']['16']['mean'], 
             data['albert-xxlarge']['dev32']['32']['mean'], 
             data['albert-xxlarge']['dev32']['64']['mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=0.4, ymax=0.65)
plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.35, ymax=0.65)

# %%
TASK = 'WSC, metric=accuracy mean value, method=cross validation'

matplotlib.rcParams.update({'font.size':15})



data_b = [data['bert-base']['cv']['8']['mean'], 
             data['bert-base']['cv']['16']['mean'], 
             data['bert-base']['cv']['32']['mean'], 
             data['bert-base']['cv']['64']['mean'], 
            ]

data_a = [data['albert-base']['cv']['8']['mean'], 
             data['albert-base']['cv']['16']['mean'], 
             data['albert-base']['cv']['32']['mean'], 
             data['albert-base']['cv']['64']['mean'], 
            ]

data_c = [data['albert-xxlarge']['cv']['8']['mean'], 
             data['albert-xxlarge']['cv']['16']['mean'], 
             data['albert-xxlarge']['cv']['32']['mean'], 
             data['albert-xxlarge']['cv']['64']['mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=0.4, ymax=0.65)
plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.35, ymax=0.65)

# %%
TASK = 'WSC, metric=accuracy mean value, method=mdl'

matplotlib.rcParams.update({'font.size':15})



data_a = [data['bert-base']['mdl']['8']['mean'], 
             data['bert-base']['mdl']['16']['mean'], 
             data['bert-base']['mdl']['32']['mean'], 
             data['bert-base']['mdl']['64']['mean'], 
            ]

data_b = [data['albert-base']['mdl']['8']['mean'], 
             data['albert-base']['mdl']['16']['mean'], 
             data['albert-base']['mdl']['32']['mean'], 
             data['albert-base']['mdl']['64']['mean'], 
            ]

data_c = [data['albert-xxlarge']['mdl']['8']['mean'], 
             data['albert-xxlarge']['mdl']['16']['mean'], 
             data['albert-xxlarge']['mdl']['32']['mean'], 
             data['albert-xxlarge']['mdl']['64']['mean'], 
            ]

# plot_bar_models(data_a, data_b, data_c, ymin=0.4, ymax=0.65)
plot_bar_models(data_a, 'albert-base (11M)', data_b, 'bert-base (110M)', 
                data_c, 'albert-xxlarge (223M)', 
                ymin=.35, ymax=0.65)
